# %%
import pandas as pd
import numpy as np

import re

from py2neo import authenticate, Graph, Node, Relationship


import os
import csv
import pickle

from time import sleep
from timeit import default_timer as timer
from datetime import datetime

from IPython.display import display, HTML

# custom general helper functions for this project
import custom_utils as cu
import importlib

# %%
from collections import defaultdict

# %%
# Note: not sure why, but on running this gensim import the kernel kept dying.
# Running the following in command line fixed it:
# conda install -f numpy
import gensim

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/arinai/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# reload imports as needed
importlib.reload(cu);

# %%
# set up Pandas options
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 100)
pd.set_option('display.precision', 3)
pd.options.display.float_format = '{:.2f}'.format

# %%
pd.options.display.max_colwidth = 100

# %%
# unpickle
with open("pickles/en_1218_louvain_communities_for_NLP.pkl", 'rb') as picklefile: 
    louvain_communities_for_NLP = pickle.load(picklefile)

louvain_communities_for_NLP.head(20)
# Out:
#     external_search_traffic  link_in_traffic  louvain_community  \
# 0                4576854.00       1108189.00                  3
# 1                3538068.00        639353.00                  4
# 2                3475113.00        223635.00                  9
# 3                3251996.00        682992.00                  4
# 4                3020671.00         31170.00                  1
# 5                2634665.00        408421.00                  4
# 6                2328884.00        200893.00                  4
# 7                2231176.00        575481.00                  3
# 8                2226602.00        117115.00                  5
# 9                2050628.00        336621.00                  5
# 10               1923035.00        109379.00                  3
# 11               1674952.00        907853.00                  3
# 12               1645911.00        137326.00                  9
# 13               1568511.00        776311.00                  5
# 14               1553836.00        260062.00                  4
# 15               1457685.00         98173.00                  4
# 16               1370107.00        442623.00                  3
# 17               1237938.00        277013.00                  4
# 18               1198082.00        381422.00                  3
# 19               1175878.00        186277.00                  3
#
#     search_in_traffic                                  title
# 0             5630.00                      George_H._W._Bush
# 1             6451.00                            Jason_Momoa
# 2            23563.00                             2.0_(film)
# 3            10416.00                        Bird_Box_(film)
# 4                 nan                              Main_Page
# 5            34309.00                         Aquaman_(film)
# 6              192.00                               Bird_Box
# 7             3945.00                        Priyanka_Chopra
# 8              958.00   List_of_most-disliked_YouTube_videos
# 9             4161.00                        Freddie_Mercury
# 10           12636.00                       Zero_(2018_film)
# 11            1273.00                         George_W._Bush
# 12            6821.00                       K.G.F:_Chapter_1
# 13            1457.00                             Nick_Jonas
# 14           26665.00      Spider-Man:_Into_the_Spider-Verse
# 15            3488.00                         Penny_Marshall
# 16            3236.00                           Jimmy_Carter
# 17            3417.00                        Macaulay_Culkin
# 18             941.00  List_of_highest-grossing_Indian_films
# 19            2082.00                   Mary,_Queen_of_Scots

# %%
len(louvain_communities_for_NLP)
# Out:
# 2729767

# %% [markdown]
# ##### Pre-process article titles

# %%
louvain_communities_for_NLP_proc =louvain_communities_for_NLP.copy()
louvain_communities_for_NLP_proc.rename(index=str,columns={'title':'title_raw'}, inplace=True)
louvain_communities_for_NLP_proc.head(5)
# Out:
#    external_search_traffic  link_in_traffic  louvain_community  \
# 0               4576854.00       1108189.00                  3
# 1               3538068.00        639353.00                  4
# 2               3475113.00        223635.00                  9
# 3               3251996.00        682992.00                  4
# 4               3020671.00         31170.00                  1
#
#    search_in_traffic          title_raw
# 0            5630.00  George_H._W._Bush
# 1            6451.00        Jason_Momoa
# 2           23563.00         2.0_(film)
# 3           10416.00    Bird_Box_(film)
# 4                nan          Main_Page

# %%
# the importance of words will be weighted by search and link traffic
louvain_communities_for_NLP_proc["weight"] = louvain_communities_for_NLP_proc[[
        "external_search_traffic", "link_in_traffic", "search_in_traffic"]].sum(axis=1).astype('int64').fillna(0)

louvain_communities_for_NLP_proc.drop(["external_search_traffic", "link_in_traffic", "search_in_traffic"], 
                                      axis = 1,
                                      inplace=True)

# %%
louvain_communities_for_NLP_proc.head(5)
# Out:
#    louvain_community          title_raw   weight
# 0                  3  George_H._W._Bush  5690673
# 1                  4        Jason_Momoa  4183872
# 2                  9         2.0_(film)  3722311
# 3                  4    Bird_Box_(film)  3945404
# 4                  1          Main_Page  3051841

# %%
# clean up the title
louvain_communities_for_NLP_proc["title"] = \
    louvain_communities_for_NLP_proc.title_raw.str.replace('_', ' ')
    
louvain_communities_for_NLP_proc.head(5)
# Out:
#    louvain_community          title_raw   weight              title
# 0                  3  George_H._W._Bush  5690673  George H. W. Bush
# 1                  4        Jason_Momoa  4183872        Jason Momoa
# 2                  9         2.0_(film)  3722311         2.0 (film)
# 3                  4    Bird_Box_(film)  3945404    Bird Box (film)
# 4                  1          Main_Page  3051841          Main Page

# %%
louvain_communities_for_NLP_proc.describe()
# Out:
#        louvain_community     weight
# count         2729767.00 2729767.00
# mean               11.48    1731.93
# std                64.77   13116.59
# min                 0.00       0.00
# 25%                 3.00      66.00
# 50%                 5.00     200.00
# 75%                10.00     735.00
# max              1697.00 5690673.00

# %%
# Use spaCy to get Named Entities

# installation instructions: https://spacy.io/usage/

import spacy
nlp = spacy.load('en', disable=['parser', 'tagger'])

# %%
nlp.pipeline
# Out:
# [('ner', <spacy.pipeline.EntityRecognizer at 0x7ff34717b780>)]

# %%
print("Started running at", datetime.now(), "UTC")

start_time = timer()

nrows = len(louvain_communities_for_NLP_proc)
print("Total number of rows to process:", nrows, "\n")

for i in range(nrows):
    txt = louvain_communities_for_NLP_proc.iloc[i].title

    doc = nlp(txt)

    ents_arr = []
    for ent in doc.ents:
        ents_arr.append(ent.label_)
    
    louvain_communities_for_NLP_proc.at[str(i), "named_entities"] = " ".join(ents_arr)
    
    if (len(louvain_communities_for_NLP_proc) > nrows):
        print("ERROR!! Dataset length has increased.")
        print("Rows processed:", round(i * 100/len(louvain_communities_for_NLP_proc), 4), "%,", "count = ", i )
        print("Elapsed time:", round((timer() - start_time)/60, 4), "min\n")
        print("Last row's processing vars:")
        print("i=", i, "txt=", txt, "ents_arr=", ents_arr, "\n",
              "updated data row:\n", louvain_communities_for_NLP_proc.iloc[i], "\n")
        break
    
    if (i % 100000 == 0):
        print("Rows processed:", round(i * 100/len(louvain_communities_for_NLP_proc), 4), "%,", "count = ", i )
        print("Elapsed time:", round((timer() - start_time)/60, 4), "min\n")
        print("Last row's processing vars:")
        print("i=", i, "txt=", txt, "ents_arr=", ents_arr, "\n",
              "updated data row:\n", louvain_communities_for_NLP_proc.iloc[i], "\n")
    

cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-01 19:57:26.153032 UTC
# Total number of rows to process: 2729767
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.0001 min
#
# Last row's processing vars:
# i= 0 txt= George H. W. Bush ents_arr= ['PERSON']
#  updated data row:
#  louvain_community                    3
# title_raw            George_H._W._Bush
# weight                         5690673
# title                George H. W. Bush
# named_entities                  PERSON
# Name: 0, dtype: object
#
# Rows processed: 3.6633 %, count =  100000
# Elapsed time: 6.8751 min
#
# Last row's processing vars:
# i= 100000 txt= List of cities and boroughs in Pennsylvania by population ents_arr= ['GPE']
#  updated data row:
#  louvain_community                                                           10
# title_raw            List_of_cities_and_boroughs_in_Pennsylvania_by_population
# weight                                                                    5628
# title                List of cities and boroughs in Pennsylvania by population
# named_entities                                                             GPE
# Name: 100000, dtype: object
#
# Rows processed: 7.3266 %, count =  200000
# Elapsed time: 13.783 min
#
# Last row's processing vars:
# i= 200000 txt= Frank Vogel ents_arr= ['PERSON']
#  updated data row:
#  louvain_community             11
# title_raw            Frank_Vogel
# weight                      3341
# title                Frank Vogel
# named_entities            PERSON
# Name: 200000, dtype: object
#
# Rows processed: 10.9899 %, count =  300000
# Elapsed time: 20.7096 min
#
# Last row's processing vars:
# i= 300000 txt= Steven Berghuis ents_arr= ['PERSON']
#  updated data row:
#  louvain_community                  3
# title_raw            Steven_Berghuis
# weight                          2758
# title                Steven Berghuis
# named_entities                PERSON
# Name: 300000, dtype: object
#
# Rows processed: 14.6533 %, count =  400000
# Elapsed time: 27.6406 min
#
# Last row's processing vars:
# i= 400000 txt= Jean Rouch ents_arr= ['PERSON']
#  updated data row:
#  louvain_community             7
# title_raw            Jean_Rouch
# weight                     1047
# title                Jean Rouch
# named_entities           PERSON
# Name: 400000, dtype: object
#
# Rows processed: 18.3166 %, count =  500000
# Elapsed time: 34.5862 min
#
# Last row's processing vars:
# i= 500000 txt= Chozhia Vellalar ents_arr= ['PERSON']
#  updated data row:
#  louvain_community                   9
# title_raw            Chozhia_Vellalar
# weight                           1115
# title                Chozhia Vellalar
# named_entities                 PERSON
# Name: 500000, dtype: object
#
# Rows processed: 21.9799 %, count =  600000
# Elapsed time: 41.5412 min
#
# Last row's processing vars:
# i= 600000 txt= Greatest (Duran Duran album) ents_arr= []
#  updated data row:
#  louvain_community                               5
# title_raw            Greatest_(Duran_Duran_album)
# weight                                       1567
# title                Greatest (Duran Duran album)
# named_entities
# Name: 600000, dtype: object
#
# Rows processed: 25.6432 %, count =  700000
# Elapsed time: 48.5261 min
#
# Last row's processing vars:
# i= 700000 txt= Russian Prussia ents_arr= ['NORP']
#  updated data row:
#  louvain_community                  3
# title_raw            Russian_Prussia
# weight                           657
# title                Russian Prussia
# named_entities                  NORP
# Name: 700000, dtype: object
#
# Rows processed: 29.3065 %, count =  800000
# Elapsed time: 55.4965 min
#
# Last row's processing vars:
# i= 800000 txt= Bus Stop (band) ents_arr= []
#  updated data row:
#  louvain_community                  5
# title_raw            Bus_Stop_(band)
# weight                           457
# title                Bus Stop (band)
# named_entities
# Name: 800000, dtype: object
#
# Rows processed: 32.9698 %, count =  900000
# Elapsed time: 62.4856 min
#
# Last row's processing vars:
# i= 900000 txt= Fijian Americans ents_arr= ['NORP']
#  updated data row:
#  louvain_community                  15
# title_raw            Fijian_Americans
# weight                            327
# title                Fijian Americans
# named_entities                   NORP
# Name: 900000, dtype: object
#
# Rows processed: 36.6332 %, count =  1000000
# Elapsed time: 69.4687 min
#
# Last row's processing vars:
# i= 1000000 txt= Federico Ricca ents_arr= ['PERSON']
#  updated data row:
#  louvain_community                 3
# title_raw            Federico_Ricca
# weight                          350
# title                Federico Ricca
# named_entities               PERSON
# Name: 1000000, dtype: object
#
# Rows processed: 40.2965 %, count =  1100000
# Elapsed time: 76.4521 min
#
# Last row's processing vars:
# i= 1100000 txt= Willie Tuitama ents_arr= ['GPE']
#  updated data row:
#  louvain_community                11
# title_raw            Willie_Tuitama
# weight                          677
# title                Willie Tuitama
# named_entities                  GPE
# Name: 1100000, dtype: object
#
# Rows processed: 43.9598 %, count =  1200000
# Elapsed time: 83.458 min
#
# Last row's processing vars:
# i= 1200000 txt= Jazz (perfume) ents_arr= []
#  updated data row:
#  louvain_community                24
# title_raw            Jazz_(perfume)
# weight                          127
# title                Jazz (perfume)
# named_entities
# Name: 1200000, dtype: object

# %% [markdown]
# The code above took a few hours to run, and finished successfully, but the browser tunnel got interrupted at some point, so the print statements above is incomplete, but the dataset has been successfully populated with named_entities.

# %%
nrows
# Out:
# 2729767

# %%
i
# Out:
# 2729766

# %%
txt
# Out:
# 'Christgau (disambiguation)'

# %%
louvain_communities_for_NLP_proc.iloc[i]
# Out:
# louvain_community                             5
# title_raw            Christgau_(disambiguation)
# weight                                       18
# title                Christgau (disambiguation)
# named_entities                              GPE
# Name: 2729766, dtype: object

# %%
louvain_communities_for_NLP_proc.head(20)
# Out:
#     louvain_community                              title_raw   weight  \
# 0                   3                      George_H._W._Bush  5690673
# 1                   4                            Jason_Momoa  4183872
# 2                   9                             2.0_(film)  3722311
# 3                   4                        Bird_Box_(film)  3945404
# 4                   1                              Main_Page  3051841
# 5                   4                         Aquaman_(film)  3077395
# 6                   4                               Bird_Box  2529969
# 7                   3                        Priyanka_Chopra  2810602
# 8                   5   List_of_most-disliked_YouTube_videos  2344675
# 9                   5                        Freddie_Mercury  2391410
# 10                  3                       Zero_(2018_film)  2045050
# 11                  3                         George_W._Bush  2584078
# 12                  9                       K.G.F:_Chapter_1  1790058
# 13                  5                             Nick_Jonas  2346279
# 14                  4      Spider-Man:_Into_the_Spider-Verse  1840563
# 15                  4                         Penny_Marshall  1559346
# 16                  3                           Jimmy_Carter  1815966
# 17                  4                        Macaulay_Culkin  1518368
# 18                  3  List_of_highest-grossing_Indian_films  1580445
# 19                  3                   Mary,_Queen_of_Scots  1364237
#
#                                     title named_entities
# 0                       George H. W. Bush         PERSON
# 1                             Jason Momoa         PERSON
# 2                              2.0 (film)       CARDINAL
# 3                         Bird Box (film)         PERSON
# 4                               Main Page         PERSON
# 5                          Aquaman (film)
# 6                                Bird Box         PERSON
# 7                         Priyanka Chopra         PERSON
# 8    List of most-disliked YouTube videos            ORG
# 9                         Freddie Mercury            ORG
# 10                       Zero (2018 film)  CARDINAL DATE
# 11                         George W. Bush         PERSON
# 12                       K.G.F: Chapter 1            LAW
# 13                             Nick Jonas         PERSON
# 14      Spider-Man: Into the Spider-Verse
# 15                         Penny Marshall         PERSON
# 16                           Jimmy Carter         PERSON
# 17                        Macaulay Culkin         PERSON
# 18  List of highest-grossing Indian films           NORP
# 19                   Mary, Queen of Scots

# %%
louvain_communities_for_NLP_proc.tail(20)
# Out:
#          louvain_community  \
# 2729747                 16
# 2729748                 13
# 2729749                 22
# 2729750                  3
# 2729751                  3
# 2729752                  2
# 2729753                  6
# 2729754                 10
# 2729755                  3
# 2729756                  7
# 2729757                  5
# 2729758                 12
# 2729759                  5
# 2729760                  7
# 2729761                  1
# 2729762                  3
# 2729763                  8
# 2729764                 12
# 2729765                  8
# 2729766                  5
#
#                                                                    title_raw  \
# 2729747                                                     Mantle_of_Luís_I
# 2729748                                   List_of_Zero:_Black_Blood_episodes
# 2729749                                                  Moskvitch_404_Sport
# 2729750                                                      Caridina_loehae
# 2729751                                                       Tatu_Miettunen
# 2729752                                                             HIST2H3C
# 2729753                                                            Muk,_Iran
# 2729754                                                       Wila,_Missouri
# 2729755                                                      Isaac_Rochussen
# 2729756                                                   Raffaello_Bertieri
# 2729757                              Project_Blues:_Saturday_Suffering_Fools
# 2729758  Swimming_at_the_2015_African_Games_–_Men's_4×100_metre_medley_relay
# 2729759                           The_Best_of_Jenny_Morris:_The_Story_So_Far
# 2729760                                              Die_Räuberbraut_(opera)
# 2729761                                           Tiefwarensee_Ice_Age_Trail
# 2729762                                                       Joel_Rajalakso
# 2729763                                                   Rocket_landing_pad
# 2729764               Athletics_at_the_Friendship_Games_–_Women's_100_metres
# 2729765                                         Bristol_Classic_Boat_Company
# 2729766                                           Christgau_(disambiguation)
#
#          weight  \
# 2729747      15
# 2729748      14
# 2729749      15
# 2729750      11
# 2729751      11
# 2729752      10
# 2729753      17
# 2729754      67
# 2729755      11
# 2729756      26
# 2729757      10
# 2729758      11
# 2729759      10
# 2729760      13
# 2729761      10
# 2729762      13
# 2729763      14
# 2729764      11
# 2729765      10
# 2729766      18
#
#                                                                        title  \
# 2729747                                                     Mantle of Luís I
# 2729748                                   List of Zero: Black Blood episodes
# 2729749                                                  Moskvitch 404 Sport
# 2729750                                                      Caridina loehae
# 2729751                                                       Tatu Miettunen
# 2729752                                                             HIST2H3C
# 2729753                                                            Muk, Iran
# 2729754                                                       Wila, Missouri
# 2729755                                                      Isaac Rochussen
# 2729756                                                   Raffaello Bertieri
# 2729757                              Project Blues: Saturday Suffering Fools
# 2729758  Swimming at the 2015 African Games – Men's 4×100 metre medley relay
# 2729759                           The Best of Jenny Morris: The Story So Far
# 2729760                                              Die Räuberbraut (opera)
# 2729761                                           Tiefwarensee Ice Age Trail
# 2729762                                                       Joel Rajalakso
# 2729763                                                   Rocket landing pad
# 2729764               Athletics at the Friendship Games – Women's 100 metres
# 2729765                                         Bristol Classic Boat Company
# 2729766                                           Christgau (disambiguation)
#
#               named_entities
# 2729747
# 2729748       CARDINAL EVENT
# 2729749             CARDINAL
# 2729750                  GPE
# 2729751
# 2729752
# 2729753              GPE GPE
# 2729754           PERSON GPE
# 2729755               PERSON
# 2729756               PERSON
# 2729757     WORK_OF_ART DATE
# 2729758  DATE EVENT QUANTITY
# 2729759
# 2729760
# 2729761                 DATE
# 2729762               PERSON
# 2729763                  GPE
# 2729764                EVENT
# 2729765                  ORG
# 2729766                  GPE

# %% [markdown]
# The named entities assignment is not perfect, for example, both "Main Page" and "Bird Box" articles were labeled "PERSON", but in many cases it did quite well.
# The "Main Page" article seems to be an important node in the network, so let's fix its named_entities value.

# %%
louvain_communities_for_NLP_proc.iloc[4]
# Out:
# louvain_community            1
# title_raw            Main_Page
# weight                 3051841
# title                Main Page
# named_entities          PERSON
# Name: 4, dtype: object

# %%
louvain_communities_for_NLP_proc.at[str(4), "named_entities"] = ''

# %%
louvain_communities_for_NLP_proc.iloc[4]
# Out:
# louvain_community            1
# title_raw            Main_Page
# weight                 3051841
# title                Main Page
# named_entities
# Name: 4, dtype: object

# %%
louvain_communities_for_NLP_proc.head(10)
# Out:
#    louvain_community                             title_raw   weight  \
# 0                  3                     George_H._W._Bush  5690673
# 1                  4                           Jason_Momoa  4183872
# 2                  9                            2.0_(film)  3722311
# 3                  4                       Bird_Box_(film)  3945404
# 4                  1                             Main_Page  3051841
# 5                  4                        Aquaman_(film)  3077395
# 6                  4                              Bird_Box  2529969
# 7                  3                       Priyanka_Chopra  2810602
# 8                  5  List_of_most-disliked_YouTube_videos  2344675
# 9                  5                       Freddie_Mercury  2391410
#
#                                   title named_entities
# 0                     George H. W. Bush         PERSON
# 1                           Jason Momoa         PERSON
# 2                            2.0 (film)       CARDINAL
# 3                       Bird Box (film)         PERSON
# 4                             Main Page
# 5                        Aquaman (film)
# 6                              Bird Box         PERSON
# 7                       Priyanka Chopra         PERSON
# 8  List of most-disliked YouTube videos            ORG
# 9                       Freddie Mercury            ORG

# %%
# pickle the output
myoutfile = "pickles/en_1218_louvain_communities_for_NLP_proc.pkl"
with open(myoutfile, 'wb') as picklefile:
    pickle.dump(louvain_communities_for_NLP_proc, picklefile)

print("Pickle created: " + myoutfile)
# Out:
# Pickle created: pickles/en_1218_louvain_communities_for_NLP_proc.pkl

# %%
# unpickle
with open("pickles/en_1218_louvain_communities_for_NLP_proc.pkl", 'rb') as picklefile: 
    louvain_communities_for_NLP_proc = pickle.load(picklefile)

louvain_communities_for_NLP_proc.head(20)
# Out:
#     louvain_community                              title_raw   weight  \
# 0                   3                      George_H._W._Bush  5690673
# 1                   4                            Jason_Momoa  4183872
# 2                   9                             2.0_(film)  3722311
# 3                   4                        Bird_Box_(film)  3945404
# 4                   1                              Main_Page  3051841
# 5                   4                         Aquaman_(film)  3077395
# 6                   4                               Bird_Box  2529969
# 7                   3                        Priyanka_Chopra  2810602
# 8                   5   List_of_most-disliked_YouTube_videos  2344675
# 9                   5                        Freddie_Mercury  2391410
# 10                  3                       Zero_(2018_film)  2045050
# 11                  3                         George_W._Bush  2584078
# 12                  9                       K.G.F:_Chapter_1  1790058
# 13                  5                             Nick_Jonas  2346279
# 14                  4      Spider-Man:_Into_the_Spider-Verse  1840563
# 15                  4                         Penny_Marshall  1559346
# 16                  3                           Jimmy_Carter  1815966
# 17                  4                        Macaulay_Culkin  1518368
# 18                  3  List_of_highest-grossing_Indian_films  1580445
# 19                  3                   Mary,_Queen_of_Scots  1364237
#
#                                     title named_entities
# 0                       George H. W. Bush         PERSON
# 1                             Jason Momoa         PERSON
# 2                              2.0 (film)       CARDINAL
# 3                         Bird Box (film)         PERSON
# 4                               Main Page
# 5                          Aquaman (film)
# 6                                Bird Box         PERSON
# 7                         Priyanka Chopra         PERSON
# 8    List of most-disliked YouTube videos            ORG
# 9                         Freddie Mercury            ORG
# 10                       Zero (2018 film)  CARDINAL DATE
# 11                         George W. Bush         PERSON
# 12                       K.G.F: Chapter 1            LAW
# 13                             Nick Jonas         PERSON
# 14      Spider-Man: Into the Spider-Verse
# 15                         Penny Marshall         PERSON
# 16                           Jimmy Carter         PERSON
# 17                        Macaulay Culkin         PERSON
# 18  List of highest-grossing Indian films           NORP
# 19                   Mary, Queen of Scots

# %%
louvain_communities_for_NLP_proc.named_entities.value_counts()
# Out:
# PERSON                                830645
#                                       814109
# ORG                                   390291
# GPE                                   170318
# DATE                                   46268
# NORP                                   38910
# GPE GPE                                38162
# CARDINAL                               29662
# ORG GPE                                28779
# PERSON GPE                             21082
# LOC                                    16358
# DATE ORG                               15102
# FAC                                    14702
# PERSON PERSON                          14446
# DATE EVENT                             14300
# PERSON DATE                            14223
# PERSON ORG                             11964
# ORG ORG                                11261
# EVENT                                  10618
# DATE GPE                               10552
# ORG DATE                                9295
# WORK_OF_ART                             8606
# ORG PERSON                              7630
# PERSON NORP                             7156
# GPE ORG                                 6698
# DATE NORP                               6308
# GPE DATE                                5328
# ORG CARDINAL                            5208
# NORP GPE                                5200
# PRODUCT                                 4824
# GPE PERSON                              4740
# CARDINAL ORG                            4632
# ORDINAL                                 4160
# DATE PERSON                             4122
# ORG GPE GPE                             3111
# ORDINAL ORG                             2688
# NORP DATE                               2473
# NORP ORG                                2403
# LOC GPE                                 2289
# CARDINAL GPE                            2275
# NORP PERSON                             2182
# CARDINAL PERSON                         2152
# DATE EVENT QUANTITY                     2142
# GPE CARDINAL                            2085
# PERSON CARDINAL                         2004
# GPE GPE GPE                             1850
# ORG NORP                                1699
# FAC GPE                                 1491
# DATE GPE GPE                            1353
# GPE DATE EVENT                          1284
#                                        ...
# ORG ORG DATE FAC                           1
# GPE ORG CARDINAL PERSON                    1
# NORP NORP DATE EVENT                       1
# TIME GPE PERSON                            1
# CARDINAL NORP TIME                         1
# CARDINAL ORG GPE CARDINAL                  1
# DATE GPE ORG EVENT                         1
# LOC PERSON EVENT                           1
# LAW PERSON ORG                             1
# PERSON GPE LOC NORP                        1
# NORP GPE LOC DATE                          1
# ORDINAL LAW GPE                            1
# PERSON PERSON ORDINAL WORK_OF_ART          1
# NORP PRODUCT NORP                          1
# GPE GPE ORG CARDINAL                       1
# CARDINAL PERSON GPE PERSON                 1
# PERSON PERSON DATE PERSON                  1
# PERCENT GPE GPE                            1
# PERSON GPE QUANTITY                        1
# CARDINAL NORP ORG CARDINAL PERSON          1
# PERSON PERSON DATE DATE                    1
# PRODUCT LOC PERSON                         1
# NORP GPE GPE GPE PERSON                    1
# MONEY PERSON ORG                           1
# GPE ORG CARDINAL ORG                       1
# PRODUCT ORG WORK_OF_ART                    1
# GPE CARDINAL CARDINAL ORG                  1
# WORK_OF_ART CARDINAL NORP                  1
# NORP PERSON CARDINAL PERSON                1
# CARDINAL NORP PERSON ORG PRODUCT           1
# CARDINAL ORDINAL DATE                      1
# PERSON PERSON PERSON GPE GPE               1
# DATE EVENT ORG DATE                        1
# ORG QUANTITY GPE                           1
# NORP CARDINAL NORP                         1
# FAC ORG WORK_OF_ART                        1
# PERSON PERSON GPE CARDINAL                 1
# TIME TIME PERSON                           1
# LOC LOC ORG NORP                           1
# GPE TIME ORG                               1
# NORP WORK_OF_ART CARDINAL                  1
# ORG NORP NORP GPE EVENT                    1
# GPE LOC PRODUCT                            1
# PERSON PERSON QUANTITY                     1
# ORG ORG LOC NORP                           1
# CARDINAL DATE PERSON PERSON PERSON         1
# LANGUAGE PERSON PERSON                     1
# GPE QUANTITY PERSON                        1
# PERSON PRODUCT WORK_OF_ART                 1
# ORG GPE ORDINAL FAC                        1
# Name: named_entities, dtype: int64

# %%
louvain_communities_for_NLP_proc[louvain_communities_for_NLP_proc.louvain_community == 14][:20]
# Out:
#        louvain_community                                   title_raw  weight  \
# 2175                  14             List_of_NHL_statistical_leaders  102869
# 3019                  14  2019_World_Junior_Ice_Hockey_Championships  117350
# 3411                  14                               Wayne_Gretzky   97377
# 3480                  14                                     24Hours   74156
# 4259                  14                 IIHF_World_U20_Championship   78838
# 4548                  14               List_of_Stanley_Cup_champions   73879
# 5399                  14                          Alexander_Ovechkin   69756
# 5408                  14  2018_World_Junior_Ice_Hockey_Championships   76122
# 5525                  14                               Sidney_Crosby   62898
# 5554                  14                                Spengler_Cup   56905
# 6472                  14                            William_Nylander   53988
# 7369                  14                              Connor_McDavid   53172
# 7413                  14                      National_Hockey_League   72391
# 8110                  14                              Miracle_on_Ice   53144
# 8285                  14                              Tyler_Bertuzzi   45429
# 9571                  14                                 Carter_Hart   39548
# 10121                 14                             Auston_Matthews   42376
# 10375                 14                     2019_NHL_Winter_Classic   41086
# 10790                 14                                  Don_Cherry   37994
# 11512                 14                            Hartford_Whalers   42674
#
#                                             title named_entities
# 2175              List of NHL statistical leaders            ORG
# 3019   2019 World Junior Ice Hockey Championships       DATE ORG
# 3411                                Wayne Gretzky         PERSON
# 3480                                      24Hours
# 4259                  IIHF World U20 Championship            ORG
# 4548                List of Stanley Cup champions          EVENT
# 5399                           Alexander Ovechkin         PERSON
# 5408   2018 World Junior Ice Hockey Championships     DATE EVENT
# 5525                                Sidney Crosby         PERSON
# 5554                                 Spengler Cup          EVENT
# 6472                             William Nylander         PERSON
# 7369                               Connor McDavid         PERSON
# 7413                       National Hockey League            ORG
# 8110                               Miracle on Ice
# 8285                               Tyler Bertuzzi            ORG
# 9571                                  Carter Hart         PERSON
# 10121                             Auston Matthews         PERSON
# 10375                     2019 NHL Winter Classic     DATE EVENT
# 10790                                  Don Cherry         PERSON
# 11512                            Hartford Whalers         PERSON

# %% [markdown]
# ##### Lemmatizing and stemming

# %%
stemmer = SnowballStemmer("english")

# %%
def parse_title(title):
    # words = re.sub('[-():]', " ", title).split()
    words = gensim.utils.simple_preprocess(title)
    stopwords = gensim.parsing.preprocessing.STOPWORDS
    
    parsed=[]
    for word in words:
        if word not in stopwords:
            lemmatized = stemmer.stem(WordNetLemmatizer().lemmatize(word, pos='v'))
            parsed.append(lemmatized)
            
    return parsed

# %%
print("Started running at", datetime.now(), "UTC")

start_time = timer()

nrows = len(louvain_communities_for_NLP_proc)
print("Num of rows:", nrows)

for i in range(nrows):
    txt = louvain_communities_for_NLP_proc.iloc[i].title
    parsed = parse_title(txt)
    
    louvain_communities_for_NLP_proc.at[str(i), "title_parsed"] = " ".join(parsed)
    
cu.printRunTime(start_time)

louvain_communities_for_NLP_proc.head(20)
# Out:
# Started running at 2019-03-03 03:58:15.950026 UTC
# Num of rows: 2729767
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 12.51 min
#     louvain_community                              title_raw   weight  \
# 0                   3                      George_H._W._Bush  5690673
# 1                   4                            Jason_Momoa  4183872
# 2                   9                             2.0_(film)  3722311
# 3                   4                        Bird_Box_(film)  3945404
# 4                   1                              Main_Page  3051841
# 5                   4                         Aquaman_(film)  3077395
# 6                   4                               Bird_Box  2529969
# 7                   3                        Priyanka_Chopra  2810602
# 8                   5   List_of_most-disliked_YouTube_videos  2344675
# 9                   5                        Freddie_Mercury  2391410
# 10                  3                       Zero_(2018_film)  2045050
# 11                  3                         George_W._Bush  2584078
# 12                  9                       K.G.F:_Chapter_1  1790058
# 13                  5                             Nick_Jonas  2346279
# 14                  4      Spider-Man:_Into_the_Spider-Verse  1840563
# 15                  4                         Penny_Marshall  1559346
# 16                  3                           Jimmy_Carter  1815966
# 17                  4                        Macaulay_Culkin  1518368
# 18                  3  List_of_highest-grossing_Indian_films  1580445
# 19                  3                   Mary,_Queen_of_Scots  1364237
#
#                                     title named_entities  \
# 0                       George H. W. Bush         PERSON
# 1                             Jason Momoa         PERSON
# 2                              2.0 (film)       CARDINAL
# 3                         Bird Box (film)         PERSON
# 4                               Main Page
# 5                          Aquaman (film)
# 6                                Bird Box         PERSON
# 7                         Priyanka Chopra         PERSON
# 8    List of most-disliked YouTube videos            ORG
# 9                         Freddie Mercury            ORG
# 10                       Zero (2018 film)  CARDINAL DATE
# 11                         George W. Bush         PERSON
# 12                       K.G.F: Chapter 1            LAW
# 13                             Nick Jonas         PERSON
# 14      Spider-Man: Into the Spider-Verse
# 15                         Penny Marshall         PERSON
# 16                           Jimmy Carter         PERSON
# 17                        Macaulay Culkin         PERSON
# 18  List of highest-grossing Indian films           NORP
# 19                   Mary, Queen of Scots
#
#                       title_parsed
# 0                       georg bush
# 1                      jason momoa
# 2                             film
# 3                    bird box film
# 4                        main page
# 5                     aquaman film
# 6                         bird box
# 7                  priyanka chopra
# 8         list dislik youtub video
# 9                   freddi mercuri
# 10                       zero film
# 11                      georg bush
# 12                         chapter
# 13                       nick jona
# 14          spider man spider vers
# 15                   penni marshal
# 16                    jimmi carter
# 17                 macaulay culkin
# 18  list highest gross indian film
# 19                 mari queen scot

# %%
# pickle the output
myoutfile = "pickles/en_1218_louvain_communities_for_NLP_proc_2.pkl"
with open(myoutfile, 'wb') as picklefile:
    pickle.dump(louvain_communities_for_NLP_proc, picklefile)

print("Pickle created: " + myoutfile)
# Out:
# Pickle created: pickles/en_1218_louvain_communities_for_NLP_proc_2.pkl

# %%
# unpickle
with open("pickles/en_1218_louvain_communities_for_NLP_proc_2.pkl", 'rb') as picklefile: 
    louvain_communities_for_NLP_proc = pickle.load(picklefile)

louvain_communities_for_NLP_proc.head(20)
# Out:
#     louvain_community                              title_raw   weight  \
# 0                   3                      George_H._W._Bush  5690673
# 1                   4                            Jason_Momoa  4183872
# 2                   9                             2.0_(film)  3722311
# 3                   4                        Bird_Box_(film)  3945404
# 4                   1                              Main_Page  3051841
# 5                   4                         Aquaman_(film)  3077395
# 6                   4                               Bird_Box  2529969
# 7                   3                        Priyanka_Chopra  2810602
# 8                   5   List_of_most-disliked_YouTube_videos  2344675
# 9                   5                        Freddie_Mercury  2391410
# 10                  3                       Zero_(2018_film)  2045050
# 11                  3                         George_W._Bush  2584078
# 12                  9                       K.G.F:_Chapter_1  1790058
# 13                  5                             Nick_Jonas  2346279
# 14                  4      Spider-Man:_Into_the_Spider-Verse  1840563
# 15                  4                         Penny_Marshall  1559346
# 16                  3                           Jimmy_Carter  1815966
# 17                  4                        Macaulay_Culkin  1518368
# 18                  3  List_of_highest-grossing_Indian_films  1580445
# 19                  3                   Mary,_Queen_of_Scots  1364237
#
#                                     title named_entities  \
# 0                       George H. W. Bush         PERSON
# 1                             Jason Momoa         PERSON
# 2                              2.0 (film)       CARDINAL
# 3                         Bird Box (film)         PERSON
# 4                               Main Page
# 5                          Aquaman (film)
# 6                                Bird Box         PERSON
# 7                         Priyanka Chopra         PERSON
# 8    List of most-disliked YouTube videos            ORG
# 9                         Freddie Mercury            ORG
# 10                       Zero (2018 film)  CARDINAL DATE
# 11                         George W. Bush         PERSON
# 12                       K.G.F: Chapter 1            LAW
# 13                             Nick Jonas         PERSON
# 14      Spider-Man: Into the Spider-Verse
# 15                         Penny Marshall         PERSON
# 16                           Jimmy Carter         PERSON
# 17                        Macaulay Culkin         PERSON
# 18  List of highest-grossing Indian films           NORP
# 19                   Mary, Queen of Scots
#
#                       title_parsed
# 0                       georg bush
# 1                      jason momoa
# 2                             film
# 3                    bird box film
# 4                        main page
# 5                     aquaman film
# 6                         bird box
# 7                  priyanka chopra
# 8         list dislik youtub video
# 9                   freddi mercuri
# 10                       zero film
# 11                      georg bush
# 12                         chapter
# 13                       nick jona
# 14          spider man spider vers
# 15                   penni marshal
# 16                    jimmi carter
# 17                 macaulay culkin
# 18  list highest gross indian film
# 19                 mari queen scot

# %% [markdown]
# Make community docs with community ids

# %%
louvain_communities_for_NLP_proc["scaled_weight"] = np.log(louvain_communities_for_NLP_proc.weight)

# %%
louvain_communities_for_NLP_proc.head()
# Out:
#    louvain_community          title_raw   weight              title  \
# 0                  3  George_H._W._Bush  5690673  George H. W. Bush
# 1                  4        Jason_Momoa  4183872        Jason Momoa
# 2                  9         2.0_(film)  3722311         2.0 (film)
# 3                  4    Bird_Box_(film)  3945404    Bird Box (film)
# 4                  1          Main_Page  3051841          Main Page
#
#   named_entities   title_parsed  scaled_weight
# 0         PERSON     georg bush          15.55
# 1         PERSON    jason momoa          15.25
# 2       CARDINAL           film          15.13
# 3         PERSON  bird box film          15.19
# 4                     main page          14.93

# %%
print("Started running at", datetime.now(), "UTC")
start_time = timer()

nrows = len(louvain_communities_for_NLP_proc)
#nrows = 10
print("Num of rows:", nrows)

communities_docs_dict = defaultdict(list)

for i in range(nrows):
    lcomm = louvain_communities_for_NLP_proc.iloc[i].louvain_community
    title_parsed_arr = louvain_communities_for_NLP_proc.iloc[i].title_parsed.split()
    named_entities_arr = louvain_communities_for_NLP_proc.iloc[i].named_entities.split()
    weight = round(louvain_communities_for_NLP_proc.iloc[i].scaled_weight).astype("int64")
    
    communities_docs_dict[lcomm].extend((title_parsed_arr + named_entities_arr) * max(weight, 1))
    
    if (i % 100000 == 0):
        print("Rows processed:", round(i * 100/len(louvain_communities_for_NLP_proc), 4), "%,", "count = ", i )
        print("Elapsed time:", round((timer() - start_time)/60, 4), "min\n")
        print("Last row's processing vars:")
        print("i=", i, "lcomm=", lcomm, "title_parsed_arr=", title_parsed_arr, 
              "named_entities_arr=", named_entities_arr,
              "weight=", weight, "\n")
    
cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 04:15:41.912996 UTC
# Num of rows: 2729767
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.0 min
#
# Last row's processing vars:
# i= 0 lcomm= 3 title_parsed_arr= ['georg', 'bush'] named_entities_arr= ['PERSON'] weight= 16
#
# Rows processed: 3.6633 %, count =  100000
# Elapsed time: 0.9798 min
#
# Last row's processing vars:
# i= 100000 lcomm= 10 title_parsed_arr= ['list', 'citi', 'borough', 'pennsylvania', 'popul'] named_entities_arr= ['GPE'] weight= 9
#
# Rows processed: 7.3266 %, count =  200000
# Elapsed time: 1.9618 min
#
# Last row's processing vars:
# i= 200000 lcomm= 11 title_parsed_arr= ['frank', 'vogel'] named_entities_arr= ['PERSON'] weight= 8
#
# Rows processed: 10.9899 %, count =  300000
# Elapsed time: 2.9442 min
#
# Last row's processing vars:
# i= 300000 lcomm= 3 title_parsed_arr= ['steven', 'berghui'] named_entities_arr= ['PERSON'] weight= 8
#
# Rows processed: 14.6533 %, count =  400000
# Elapsed time: 3.9236 min
#
# Last row's processing vars:
# i= 400000 lcomm= 7 title_parsed_arr= ['jean', 'rouch'] named_entities_arr= ['PERSON'] weight= 7
#
# Rows processed: 18.3166 %, count =  500000
# Elapsed time: 4.9034 min
#
# Last row's processing vars:
# i= 500000 lcomm= 9 title_parsed_arr= ['chozhia', 'vellalar'] named_entities_arr= ['PERSON'] weight= 7
#
# Rows processed: 21.9799 %, count =  600000
# Elapsed time: 5.8819 min
#
# Last row's processing vars:
# i= 600000 lcomm= 5 title_parsed_arr= ['greatest', 'duran', 'duran', 'album'] named_entities_arr= [] weight= 7
#
# Rows processed: 25.6432 %, count =  700000
# Elapsed time: 6.8648 min
#
# Last row's processing vars:
# i= 700000 lcomm= 3 title_parsed_arr= ['russian', 'prussia'] named_entities_arr= ['NORP'] weight= 6
#
# Rows processed: 29.3065 %, count =  800000
# Elapsed time: 7.846 min
#
# Last row's processing vars:
# i= 800000 lcomm= 5 title_parsed_arr= ['bus', 'stop', 'band'] named_entities_arr= [] weight= 6
#
# Rows processed: 32.9698 %, count =  900000
# Elapsed time: 8.8272 min
#
# Last row's processing vars:
# i= 900000 lcomm= 15 title_parsed_arr= ['fijian', 'american'] named_entities_arr= ['NORP'] weight= 6
#
# Rows processed: 36.6332 %, count =  1000000
# Elapsed time: 9.8023 min
#
# Last row's processing vars:
# i= 1000000 lcomm= 3 title_parsed_arr= ['federico', 'ricca'] named_entities_arr= ['PERSON'] weight= 6
#
# Rows processed: 40.2965 %, count =  1100000
# Elapsed time: 10.7779 min
#
# Last row's processing vars:
# i= 1100000 lcomm= 11 title_parsed_arr= ['willi', 'tuitama'] named_entities_arr= ['GPE'] weight= 7
#
# Rows processed: 43.9598 %, count =  1200000
# Elapsed time: 11.7529 min
#
# Last row's processing vars:
# i= 1200000 lcomm= 24 title_parsed_arr= ['jazz', 'perfum'] named_entities_arr= [] weight= 5
#
# Rows processed: 47.6231 %, count =  1300000
# Elapsed time: 12.7287 min
#
# Last row's processing vars:
# i= 1300000 lcomm= 11 title_parsed_arr= ['westport', 'high', 'school', 'missouri'] named_entities_arr= ['ORG', 'GPE'] weight= 5
#
# Rows processed: 51.2864 %, count =  1400000
# Elapsed time: 13.7019 min
#
# Last row's processing vars:
# i= 1400000 lcomm= 3 title_parsed_arr= ['footbal', 'feder', 'burundi'] named_entities_arr= ['ORG'] weight= 5
#
# Rows processed: 54.9497 %, count =  1500000
# Elapsed time: 14.6758 min
#
# Last row's processing vars:
# i= 1500000 lcomm= 6 title_parsed_arr= ['raul', 'pangalangan'] named_entities_arr= ['PERSON'] weight= 5
#
# Rows processed: 58.6131 %, count =  1600000
# Elapsed time: 15.6494 min
#
# Last row's processing vars:
# i= 1600000 lcomm= 3 title_parsed_arr= ['cabinet', 'andrej', 'plenković'] named_entities_arr= [] weight= 5
#
# Rows processed: 62.2764 %, count =  1700000
# Elapsed time: 16.6217 min
#
# Last row's processing vars:
# i= 1700000 lcomm= 4 title_parsed_arr= ['love', 'island', 'film'] named_entities_arr= ['DATE'] weight= 5
#
# Rows processed: 65.9397 %, count =  1800000
# Elapsed time: 17.5951 min
#
# Last row's processing vars:
# i= 1800000 lcomm= 9 title_parsed_arr= ['kothandarama', 'templ', 'thillaivilagam'] named_entities_arr= ['PERSON', 'ORG'] weight= 4
#
# Rows processed: 69.603 %, count =  1900000
# Elapsed time: 18.5672 min
#
# Last row's processing vars:
# i= 1900000 lcomm= 6 title_parsed_arr= ['sultan', 'al', 'neyadi'] named_entities_arr= ['PERSON'] weight= 6
#
# Rows processed: 73.2663 %, count =  2000000
# Elapsed time: 19.5382 min
#
# Last row's processing vars:
# i= 2000000 lcomm= 10 title_parsed_arr= ['brooklin', 'hill', 'station'] named_entities_arr= ['GPE'] weight= 4
#
# Rows processed: 76.9296 %, count =  2100000
# Elapsed time: 20.5119 min
#
# Last row's processing vars:
# i= 2100000 lcomm= 7 title_parsed_arr= ['ladislav', 'šaloun'] named_entities_arr= ['PERSON'] weight= 4
#
# Rows processed: 80.593 %, count =  2200000
# Elapsed time: 21.4844 min
#
# Last row's processing vars:
# i= 2200000 lcomm= 13 title_parsed_arr= ['acorn', 'user'] named_entities_arr= [] weight= 3
#
# Rows processed: 84.2563 %, count =  2300000
# Elapsed time: 22.4569 min
#
# Last row's processing vars:
# i= 2300000 lcomm= 10 title_parsed_arr= ['blosenbergturm'] named_entities_arr= [] weight= 4
#
# Rows processed: 87.9196 %, count =  2400000
# Elapsed time: 23.4288 min
#
# Last row's processing vars:
# i= 2400000 lcomm= 4 title_parsed_arr= ['glori', 'film'] named_entities_arr= ['DATE'] weight= 4
#
# Rows processed: 91.5829 %, count =  2500000
# Elapsed time: 24.4011 min
#
# Last row's processing vars:
# i= 2500000 lcomm= 3 title_parsed_arr= ['gwenyfr', 'bush'] named_entities_arr= ['PERSON'] weight= 3
#
# Rows processed: 95.2462 %, count =  2600000
# Elapsed time: 25.3723 min
#
# Last row's processing vars:
# i= 2600000 lcomm= 7 title_parsed_arr= ['david', 'levin', 'disambigu'] named_entities_arr= ['PERSON'] weight= 3
#
# Rows processed: 98.9095 %, count =  2700000
# Elapsed time: 26.3429 min
#
# Last row's processing vars:
# i= 2700000 lcomm= 7 title_parsed_arr= ['central', 'teke', 'languag'] named_entities_arr= ['PERSON'] weight= 2
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 26.63 min

# %%
count = 0
for k, v in communities_docs_dict.items():
    print("\n", k, "\n", "doc length=", len(v), "\ndoc sample tokens:", v[:10])
    count += 1
    if count > 9:
        break
# Out:
#  0
#  doc length= 536013
# doc sample tokens: ['pink', 'line', 'delhi', 'metro', 'pink', 'line', 'delhi', 'metro', 'pink', 'line']
#
#  1
#  doc length= 3343973
# doc sample tokens: ['main', 'page', 'main', 'page', 'main', 'page', 'main', 'page', 'main', 'page']
#
#  2
#  doc length= 2862788
# doc sample tokens: ['list', 'presid', 'unit', 'state', 'date', 'death', 'GPE', 'list', 'presid', 'unit']
#
#  3
#  doc length= 9786326
# doc sample tokens: ['georg', 'bush', 'PERSON', 'georg', 'bush', 'PERSON', 'georg', 'bush', 'PERSON', 'georg']
#
#  4
#  doc length= 5335393
# doc sample tokens: ['jason', 'momoa', 'PERSON', 'jason', 'momoa', 'PERSON', 'jason', 'momoa', 'PERSON', 'jason']
#
#  5
#  doc length= 4009506
# doc sample tokens: ['list', 'dislik', 'youtub', 'video', 'ORG', 'list', 'dislik', 'youtub', 'video', 'ORG']
#
#  6
#  doc length= 1536687
# doc sample tokens: ['meg', 'johnson', 'poet', 'PERSON', 'meg', 'johnson', 'poet', 'PERSON', 'meg', 'johnson']
#
#  7
#  doc length= 4911364
# doc sample tokens: ['box', 'day', 'box', 'day', 'box', 'day', 'box', 'day', 'box', 'day']
#
#  8
#  doc length= 1356088
# doc sample tokens: ['attack', 'pearl', 'harbor', 'FAC', 'attack', 'pearl', 'harbor', 'FAC', 'attack', 'pearl']
#
#  9
#  doc length= 737029
# doc sample tokens: ['film', 'CARDINAL', 'film', 'CARDINAL', 'film', 'CARDINAL', 'film', 'CARDINAL', 'film', 'CARDINAL']

# %%
# pickle the output
myoutfile = "pickles/en_1218_louvain_communities_docs_dict.pkl"
with open(myoutfile, 'wb') as picklefile:
    pickle.dump(communities_docs_dict, picklefile)

print("Pickle created: " + myoutfile)
# Out:
# Pickle created: pickles/en_1218_louvain_communities_docs_dict.pkl

# %%
# unpickle
with open("pickles/en_1218_louvain_communities_docs_dict.pkl", 'rb') as picklefile: 
    communities_docs_dict = pickle.load(picklefile)

count = 0
for k, v in communities_docs_dict.items():
    print("\n", k, "\n", "doc length=", len(v), "\ndoc sample tokens:", v[:10])
    count += 1
    if count > 9:
        break
# Out:
#  0
#  doc length= 536013
# doc sample tokens: ['pink', 'line', 'delhi', 'metro', 'pink', 'line', 'delhi', 'metro', 'pink', 'line']
#
#  1
#  doc length= 3343973
# doc sample tokens: ['main', 'page', 'main', 'page', 'main', 'page', 'main', 'page', 'main', 'page']
#
#  2
#  doc length= 2862788
# doc sample tokens: ['list', 'presid', 'unit', 'state', 'date', 'death', 'GPE', 'list', 'presid', 'unit']
#
#  3
#  doc length= 9786326
# doc sample tokens: ['georg', 'bush', 'PERSON', 'georg', 'bush', 'PERSON', 'georg', 'bush', 'PERSON', 'georg']
#
#  4
#  doc length= 5335393
# doc sample tokens: ['jason', 'momoa', 'PERSON', 'jason', 'momoa', 'PERSON', 'jason', 'momoa', 'PERSON', 'jason']
#
#  5
#  doc length= 4009506
# doc sample tokens: ['list', 'dislik', 'youtub', 'video', 'ORG', 'list', 'dislik', 'youtub', 'video', 'ORG']
#
#  6
#  doc length= 1536687
# doc sample tokens: ['meg', 'johnson', 'poet', 'PERSON', 'meg', 'johnson', 'poet', 'PERSON', 'meg', 'johnson']
#
#  7
#  doc length= 4911364
# doc sample tokens: ['box', 'day', 'box', 'day', 'box', 'day', 'box', 'day', 'box', 'day']
#
#  8
#  doc length= 1356088
# doc sample tokens: ['attack', 'pearl', 'harbor', 'FAC', 'attack', 'pearl', 'harbor', 'FAC', 'attack', 'pearl']
#
#  9
#  doc length= 737029
# doc sample tokens: ['film', 'CARDINAL', 'film', 'CARDINAL', 'film', 'CARDINAL', 'film', 'CARDINAL', 'film', 'CARDINAL']

# %%
# make a list of doc lists (needed for gensim inputs), and a community2doc lookup dict

print("Started running at", datetime.now(), "UTC")
start_time = timer()

community_docs_list = [] # list of doc lists
community2doc = {} # comm id is key and list doc index in community_docs_list is value

i = 0
for k, v in communities_docs_dict.items():
    community_docs_list.append(v)
    community2doc[k] = i
    i += 1

    
cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 04:42:30.608266 UTC
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 0.0 min

# %%
len(community_docs_list)
# Out:
# 1698

# %%
# 1698

# %% [markdown]
# #### Bags of words

# %% [markdown]
# ##### Dataset bag of words

# %%
# this is just an id2word mapping (the integer keys here are ids, not counts)
dictionary = gensim.corpora.Dictionary(community_docs_list)

# check results
i = 0
for k, v in dictionary.items():
    print(k, v)
    i += 1
    if i > 5:
        break
# Out:
# 152479 myponga
# 222740 doosri
# 527118 patroon
# 60675 mislead
# 360370 pavlína
# 524362 mancusi

# %%
# Filtering
#dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
dictionary.filter_extremes(no_above=0.1)

# %%
# make bags of words for each doc in docs list, forming the corpus input for LDA model

print("Started running at", datetime.now(), "UTC")
start_time = timer()

bow_corpus = [dictionary.doc2bow(doc) for doc in community_docs_list]

cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 05:07:43.481396 UTC
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 0.26 min

# %%
document_num = 0
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x[:10])):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 0 ("EVENT") appears 468 time.
# Word 1 ("FAC") appears 4963 time.
# Word 2 ("LANGUAGE") appears 19 time.
# Word 3 ("LAW") appears 29 time.
# Word 4 ("LOC") appears 2929 time.
# Word 5 ("MONEY") appears 24 time.
# Word 6 ("ORDINAL") appears 350 time.
# Word 7 ("PRODUCT") appears 743 time.
# Word 8 ("QUANTITY") appears 36 time.
# Word 9 ("TIME") appears 24 time.

# %%
# Run LDA multicore

print("Started running at", datetime.now(), "UTC")
start_time = timer()

lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 10, 
                                   id2word = dictionary,                                    
                                   passes = 20,
                                   workers = 4)


cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 05:17:45.023803 UTC
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 2.29 min

# %%
for idx, topic in lda_model.print_topics(-1):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.061*"EVENT" + 0.039*"championship" + 0.031*"olymp" + 0.029*"world" + 0.022*"summer" + 0.019*"men" + 0.016*"game" + 0.014*"hockey" + 0.013*"women" + 0.012*"QUANTITY"
#
#
# Topic: 1
# Words: 0.043*"song" + 0.014*"band" + 0.009*"discographi" + 0.009*"love" + 0.008*"music" + 0.007*"live" + 0.007*"WORK_OF_ART" + 0.005*"musician" + 0.005*"record" + 0.005*"tour"
#
#
# Topic: 2
# Words: 0.025*"station" + 0.023*"railway" + 0.022*"airport" + 0.018*"FAC" + 0.015*"class" + 0.015*"air" + 0.013*"uss" + 0.010*"cricket" + 0.008*"rugbi" + 0.008*"hms"
#
#
# Topic: 3
# Words: 0.014*"state" + 0.013*"new" + 0.012*"counti" + 0.009*"LOC" + 0.008*"school" + 0.008*"unit" + 0.008*"FAC" + 0.007*"california" + 0.007*"york" + 0.006*"station"
#
#
# Topic: 4
# Words: 0.006*"disambigu" + 0.005*"LOC" + 0.005*"engin" + 0.004*"seri" + 0.004*"softwar" + 0.004*"PRODUCT" + 0.004*"station" + 0.004*"power" + 0.003*"grand" + 0.003*"prix"
#
#
# Topic: 5
# Words: 0.037*"footbal" + 0.028*"team" + 0.026*"season" + 0.018*"school" + 0.015*"basketbal" + 0.013*"high" + 0.011*"EVENT" + 0.010*"leagu" + 0.009*"american" + 0.008*"state"
#
#
# Topic: 6
# Words: 0.045*"film" + 0.013*"seri" + 0.011*"tv" + 0.010*"game" + 0.007*"WORK_OF_ART" + 0.006*"actor" + 0.006*"video" + 0.006*"episod" + 0.006*"award" + 0.005*"disambigu"
#
#
# Topic: 7
# Words: 0.008*"disambigu" + 0.006*"church" + 0.005*"al" + 0.004*"john" + 0.004*"LOC" + 0.004*"languag" + 0.004*"novel" + 0.003*"saint" + 0.003*"film" + 0.003*"st"
#
#
# Topic: 8
# Words: 0.014*"univers" + 0.007*"school" + 0.007*"colleg" + 0.006*"disambigu" + 0.005*"bank" + 0.005*"nation" + 0.004*"compani" + 0.004*"institut" + 0.004*"state" + 0.003*"intern"
#
#
# Topic: 9
# Words: 0.011*"unit" + 0.010*"state" + 0.009*"footbal" + 0.007*"nation" + 0.007*"EVENT" + 0.005*"ORDINAL" + 0.005*"th" + 0.005*"constitu" + 0.005*"LOC" + 0.005*"parti"

# %% [markdown]
# Let's try looking at the topics individually: a given topic is the dataset, and a parsed article title is a doc.

# %%
louvain_communities_for_NLP_proc[louvain_communities_for_NLP_proc.louvain_community == 11].head(5)
# Out:
#      louvain_community                         title_raw  weight  \
# 74                  11                   Patrick_Mahomes  669193
# 78                  11                      Kyler_Murray  630603
# 103                 11                      LeBron_James  621114
# 110                 11                     Philip_Rivers  544167
# 120                 11  2018–19_NCAA_football_bowl_games  514981
#
#                                 title named_entities            title_parsed  \
# 74                    Patrick Mahomes         PERSON           patrick mahom
# 78                       Kyler Murray         PERSON            kyler murray
# 103                      LeBron James         PERSON              lebron jam
# 110                     Philip Rivers         PERSON            philip river
# 120  2018–19 NCAA football bowl games            ORG  ncaa footbal bowl game
#
#      scaled_weight
# 74           13.41
# 78           13.35
# 103          13.34
# 110          13.21
# 120          13.15

# %%
test_community = louvain_communities_for_NLP_proc[louvain_communities_for_NLP_proc.louvain_community == 11].copy()

# %%
test_community.describe()
# Out:
#        louvain_community    weight  scaled_weight
# count          110397.00 110397.00      110397.00
# mean               11.00   1584.24           -inf
# std                 0.00   9576.18            nan
# min                11.00      0.00           -inf
# 25%                11.00     62.00           4.13
# 50%                11.00    171.00           5.14
# 75%                11.00    609.00           6.41
# max                11.00 669193.00          13.41

# %%
test_community[(test_community.named_entities != "PERSON")].head(5)
# Out:
#      louvain_community                                            title_raw  \
# 120                 11                     2018–19_NCAA_football_bowl_games
# 252                 11  2019_College_Football_Playoff_National_Championship
# 296                 11                                          Urban_Meyer
# 312                 11                             College_Football_Playoff
# 323                 11                         List_of_Super_Bowl_champions
#
#      weight                                                title  \
# 120  514981                     2018–19 NCAA football bowl games
# 252  367824  2019 College Football Playoff National Championship
# 296  326946                                          Urban Meyer
# 312  346983                             College Football Playoff
# 323  350514                         List of Super Bowl champions
#
#     named_entities                                title_parsed  scaled_weight
# 120            ORG                      ncaa footbal bowl game          13.15
# 252           DATE  colleg footbal playoff nation championship          12.82
# 296                                                urban meyer          12.70
# 312                                     colleg footbal playoff          12.76
# 323          EVENT                    list super bowl champion          12.77

# %%
test_community = test_community[(test_community.named_entities != "PERSON")]

# %%
len(test_community)
# Out:
# 62724

# %%
test_community.head()
# Out:
#      louvain_community                                            title_raw  \
# 120                 11                     2018–19_NCAA_football_bowl_games
# 252                 11  2019_College_Football_Playoff_National_Championship
# 296                 11                                          Urban_Meyer
# 312                 11                             College_Football_Playoff
# 323                 11                         List_of_Super_Bowl_champions
#
#      weight                                                title  \
# 120  514981                     2018–19 NCAA football bowl games
# 252  367824  2019 College Football Playoff National Championship
# 296  326946                                          Urban Meyer
# 312  346983                             College Football Playoff
# 323  350514                         List of Super Bowl champions
#
#     named_entities                                title_parsed  scaled_weight
# 120            ORG                      ncaa footbal bowl game          13.15
# 252           DATE  colleg footbal playoff nation championship          12.82
# 296                                                urban meyer          12.70
# 312                                     colleg footbal playoff          12.76
# 323          EVENT                    list super bowl champion          12.77

# %%
print("Started running at", datetime.now(), "UTC")
start_time = timer()

nrows = len(test_community)
# nrows = 10
print("Num of rows:", nrows)

article_docs = []

for i in range(nrows):
    title_parsed_arr = test_community.iloc[i].title_parsed.split()
    named_entities_arr = test_community.iloc[i].named_entities.split()
    weight = max(round(test_community.iloc[i].scaled_weight).astype("int64"), 1)
    
    # article_docs.append((title_parsed_arr + named_entities_arr) * weight)
    for i in range(weight):
        article_docs.append(title_parsed_arr + named_entities_arr)
    #article_docs.append(title_parsed_arr + named_entities_arr)
    
    
    if (i % 10000 == 0):
        print("Rows processed:", round(i * 100/len(test_community), 4), "%,", "count = ", i )
        print("Elapsed time:", round((timer() - start_time)/60, 4), "min\n")
        print("Last row's processing vars:")
        print("i=", i, "title_parsed_arr=", title_parsed_arr, 
              "named_entities_arr=", named_entities_arr,
              "weight=", weight, "\n")
    
cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 18:49:19.305972 UTC
# Num of rows: 62724
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4626 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['buffalo', 'american', 'season'] named_entities_arr= ['CARDINAL', 'GPE', 'NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4629 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['yale', 'bulldog', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4631 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['atlant', 'sun'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4632 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['detroit', 'tiger', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4633 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['stauska'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4633 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sewickley'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4638 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kallman'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4638 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['caribbean', 'seri'] named_entities_arr= ['EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4638 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mountain', 'west', 'confer', 'tournament'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4639 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['auburn', 'tiger', 'footbal', 'team'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4645 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['san', 'diego', 'padr', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4646 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['illinoi', 'fight', 'illini', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4647 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['calath'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4649 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['osweil'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4654 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['garnett'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4656 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['poli', 'well', 'field'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4656 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['elway'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4657 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kinsler'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4663 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['california', 'angel', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4664 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tulan', 'green', 'wave', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4665 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['westervill'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4665 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4665 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kansa', 'state', 'wildcat', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4666 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['nebraska', 'cornhusk', 'footbal', 'team'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4672 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['california', 'golden', 'bear', 'footbal', 'team'] named_entities_arr= ['DATE', 'FAC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4673 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['hisd'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4674 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['basketbal'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4674 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lsu', 'tiger', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4678 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['nichol', 'state', 'colonel', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.468 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['chanut'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4682 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['moorestown'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4684 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['pablo', 'aguilar', 'footbal', 'bear'] named_entities_arr= ['ORG', 'DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4684 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sewane', 'tiger', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4685 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['klay'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4685 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['minnesota', 'twin', 'season'] named_entities_arr= ['DATE', 'EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4692 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kinston'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4695 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['gallinari'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4697 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['proposit'] named_entities_arr= ['CARDINAL'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4698 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['stanford', 'indian', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG', 'NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4698 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['texa', 'longhorn', 'basketbal'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4702 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['fiba', 'europ', 'championship'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4706 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['heinsohn'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4711 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['confer', 'usa', 'tournament'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4711 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['haynesworth'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4711 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['meadowland', 'stadium'] named_entities_arr= ['FAC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4712 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['virginia', 'tech', 'gobbler', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4713 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['van', 'noy'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4714 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mississippi', 'state', 'maroon', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4715 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['alliquippa'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4718 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['chapman', 'elementari', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4718 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mvfc'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.472 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['diaw'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.472 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['circus', 'world'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.472 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= [] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4723 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['commonwealth', 'stadium'] named_entities_arr= ['FAC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4725 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['san', 'jose', 'state', 'spartan', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4726 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mixon'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4728 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['cp'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4728 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['miami', 'hurrican', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4732 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ohio', 'state', 'basketbal'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4732 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['orang', 'counti', 'soccer', 'club'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4733 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['utah', 'ute', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4733 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['krxo'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4738 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sinch'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4742 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['calgari', 'stamped', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4743 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['klieman'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4743 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['parcel'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4747 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['montana', 'grizzli', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4747 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['minnesota', 'golden', 'gopher', 'footbal', 'team'] named_entities_arr= ['DATE', 'FAC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4754 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sportsnat'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4754 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['fiba', 'europ', 'championship'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4755 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lee', 'counti', 'school', 'district'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4755 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sumlin'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4755 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['portland', 'public', 'school'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4756 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['spearvill'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4756 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['vic', 'power'] named_entities_arr= ['PRODUCT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4757 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['william', 'jone', 'cup'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4757 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4758 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tannehil'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4758 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lemont'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4764 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['marburi'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4765 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4766 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['azubuik'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4768 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['saboni'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4769 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['monday', 'night', 'miracl'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4772 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['footbal', 'bonair'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4773 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['virginia', 'cavali', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4774 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['halifax', 'wander'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4776 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['butler', 'basketbal'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4778 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ucla', 'bruin', 'footbal', 'team'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4781 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['offerman'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4781 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['list', 'footbal', 'club', 'sint', 'maarten'] named_entities_arr= ['LOC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4791 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['northwest', 'leagu', 'roster'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4796 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['haslam'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4799 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4799 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['brownsburg'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.48 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['petrino'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4801 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lincecum'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4802 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['vanderbilt', 'commodor', 'footbal', 'team'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4804 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['footbal', 'saint', 'vincent', 'grenadin'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4807 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['cifl', 'championship', 'game'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4808 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['collegeinsid', 'com', 'postseason', 'tournament'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4809 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['nll', 'team', 'capsul'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4811 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['unlv', 'rebel', 'footbal', 'team'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4812 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['boston', 'renegad'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4815 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['haslem'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4815 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['augustana', 'colleg'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4815 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['basebal', 'hall', 'fame', 'ballot'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4817 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['fairview', 'park'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4819 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['bls', 'super', 'leagu', 'mvp'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.482 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['indianapoli', 'public', 'school', 'confer'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.482 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['east', 'carolina', 'pirat', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4822 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wnba', 'star', 'game'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4823 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['walt', 'disney', 'world', 'pro', 'soccer', 'classic'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4825 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lynbrook', 'union', 'free', 'school', 'district'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4826 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['footbal', 'british', 'virgin', 'island'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4828 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sprole'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.483 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['list', 'costa', 'rican', 'provinc', 'human', 'develop', 'index'] named_entities_arr= ['NORP', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4832 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['georgia', 'tech', 'yellow', 'jacket', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4833 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['footbal', 'saint', 'kitt', 'nevi'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4835 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['winnipeg', 'blue', 'bomber', 'season'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4836 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['air', 'forc', 'falcon', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4838 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['purdu', 'boilermak', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4839 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wjth'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4841 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['base'] named_entities_arr= ['ORDINAL'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4844 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['georgia', 'tech', 'yellow', 'jacket', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4845 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['footbal', 'grenada'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4846 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['texa', 'ranger', 'season'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4846 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['european', 'ladi', 'amateur', 'championship'] named_entities_arr= ['NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4847 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ktck'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4847 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['buffalo', 'bison', 'nfl', 'season'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4851 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['zenner'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4852 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4852 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['chippewa', 'middl', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4853 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['maryland', 'terrapin', 'basketbal'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4854 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['espn', 'radio'] named_entities_arr= ['CARDINAL', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4861 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tskitishvili'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4863 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['florida', 'striker'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4864 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['trumain'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4865 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['winnipeg', 'blue', 'bomber', 'season'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4865 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['illinoi', 'fight', 'illini', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4866 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['usc', 'basketbal'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4867 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['pacif', 'tiger', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4868 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['urschel'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4868 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['studdard'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4875 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['new', 'zealand', 'nbl', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4875 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['montreal', 'alouett', 'season'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.488 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['leagu', 'australia'] named_entities_arr= ['DATE', 'ORG', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4881 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['london', 'lion'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4886 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['polk', 'counti', 'school', 'district'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4886 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['valvano'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4889 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['troy', 'state', 'trojan', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4891 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['houston', 'astro', 'season'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4893 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['pdl', 'season'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4893 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['seattl', 'marin', 'season'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4897 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['champion', 'indoor', 'footbal', 'season'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.49 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['st', 'vincent', 'colleg', 'pennsylvania'] named_entities_arr= ['ORG', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.49 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['zoubek'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4905 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['plantsvill'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4906 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['delawar', 'state', 'hornet', 'footbal', 'team'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4908 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['struna'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.491 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mathewson'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4911 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['flea', 'flicker'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4912 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ghsa'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4912 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4913 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['franc', 'nation', 'basketbal', 'team'] named_entities_arr= ['GPE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4913 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['brownwood'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4917 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4917 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tressel'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4923 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sandersvill'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4923 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['northwestern', 'purpl', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4923 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kiker'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4926 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kears'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4929 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mckinni'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4933 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['copa', 'del', 'rey', 'baloncesto'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4933 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['minnesota', 'twin', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.494 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['northern', 'arizona', 'lumberjack', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4941 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mile', 'field', 'virginia', 'tech'] named_entities_arr= ['GPE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4945 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tour'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4947 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['pompano', 'beach', 'cub'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.495 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kliff'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.495 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['shved'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4953 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['foxworth'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4955 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['minnesota', 'twin', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.496 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['uwlx', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4962 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'divis', 'basebal', 'season'] named_entities_arr= ['ORG', 'DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4963 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['boardwalk', 'classic'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4967 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ski', 'mah'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4968 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['iowa', 'hawkey', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4973 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ole', 'miss', 'rebel', 'basebal', 'team'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4973 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['theismann'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4975 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['california', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4975 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['hamburg', 'sea', 'devil', 'season'] named_entities_arr= ['DATE', 'LOC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4976 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['centervill', 'citi', 'school', 'district'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4976 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['johnsburg'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.498 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['slipperi', 'rock'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4983 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['boston', 'be', 'season'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4984 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['texa', 'lone', 'star', 'striker'] named_entities_arr= ['GPE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4985 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['cup'] named_entities_arr= ['DATE', 'EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4986 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mullen'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4992 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['uk', 'basketbal'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4992 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['heinick'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4993 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kleiza'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4995 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['columbus', 'lion', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4995 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['american', 'dream', 'mall'] named_entities_arr= ['NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4996 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['clowney'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4997 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tarkanian'] named_entities_arr= ['NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4997 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wcu'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.4999 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['chadron'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5001 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['clemson', 'tiger', 'footbal', 'team'] named_entities_arr= ['CARDINAL', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5002 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wnbl'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5002 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ball'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5004 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['albani', 'empir'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5005 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wxks'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5006 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['neali'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.501 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5011 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['saint', 'franci', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5012 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['allanson'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5012 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5012 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['soccer', 'bowl'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5015 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['calgari', 'stamped', 'season'] named_entities_arr= ['CARDINAL', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5015 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['peyto'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5022 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['bogu'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5024 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['world', 'cup'] named_entities_arr= ['DATE', 'EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5025 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['european', 'basebal', 'championship'] named_entities_arr= ['DATE', 'EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5026 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['usc', 'trojan', 'basketbal'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5027 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5028 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['richland'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.503 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['west', 'alabama', 'tiger', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.503 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mcmani'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5034 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['panther', 'stadium'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5035 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['avca', 'showcas'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5035 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['big', 'confer', 'footbal', 'team'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5038 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['toronto', 'argonaut', 'season'] named_entities_arr= ['DATE', 'EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5039 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['florida', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5042 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['honduran', 'supercup'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5043 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['pioneer', 'leagu'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5043 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['whisenhunt'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5045 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['houston', 'astro', 'season'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5045 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['hancevill'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5047 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kent', 'state', 'golden', 'flash', 'footbal', 'team'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5048 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5049 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['pittsburgh', 'pirat', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.505 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['detroit', 'wolverin', 'season'] named_entities_arr= ['DATE', 'GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5052 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['greg', 'jone', 'american', 'footbal'] named_entities_arr= ['PERSON', 'NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5054 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['point'] named_entities_arr= ['CARDINAL'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5057 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['atkinson', 'elementari', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5059 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['spoelstra'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.506 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['divincenzo'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5061 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['footbal', 'sint', 'maarten'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5061 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['arizona', 'state', 'sun', 'devil', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5063 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['develin'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5065 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['notr', 'dame', 'fight', 'irish', 'basketbal'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5066 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mercer', 'bear', 'footbal', 'team'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5067 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wnba', 'playoff'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5068 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['gudaiti'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5071 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['manut'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5074 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5075 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['north', 'carolina', 'tar', 'heel', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5077 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['georgia', 'footbal', 'team'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5082 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['los', 'angel', 'express'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5083 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['brile'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5083 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['trevathan'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5084 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['CARDINAL', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5084 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['tulsa', 'golden', 'hurrican', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5084 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['south', 'carolina', 'gamecock', 'basketbal'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5087 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['california', 'golden', 'bear', 'footbal', 'team'] named_entities_arr= ['DATE', 'FAC'] weight= 1
#
# ...
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.523 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['thorsbi'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.523 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['headrick'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.523 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['feeley'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['bloomingburg'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['virden'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['seffner'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ambrosi'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['chidest'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['clifti'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['stargel'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['okajima'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sochor'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5231 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['bunch'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['manasquan'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['brotherson'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['dalevill'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['shorewood'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['dennard'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['elkmont'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['bridwel'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sumral'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ihsaa'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mcdaniel'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5232 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wawaka'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5233 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['koss'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5233 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mattawan'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5233 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['whiteland'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5233 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['doud'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5233 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['stagg', 'high', 'school'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5234 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kansa', 'citi', 'school', 'district'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5234 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['michigan', 'state', 'spartan', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5235 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['draft'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5235 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['elkin', 'high', 'school'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5235 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['walton', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5235 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['sunday', 'night', 'footbal', 'result'] named_entities_arr= ['WORK_OF_ART'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5235 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['carter', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5235 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['st', 'loui', 'star'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5236 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5236 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wrch'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5237 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ksps'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5238 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['hogeboom'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5238 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5238 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['readi'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5238 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['nbpa'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5239 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['papagianni'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5239 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5239 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['usc', 'methodist', 'footbal', 'team'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5239 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['denver', 'pioneer', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5239 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['ncaa', 'footbal', 'bowl', 'game'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.524 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['big', 'basketbal', 'tournament'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.524 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.524 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['draft'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.524 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['guoka'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.524 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['battier'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5241 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['adriat', 'leagu'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5241 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['huntington', 'univers'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5242 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['triniti', 'christian', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5242 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['bogut'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5242 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['fresno', 'state', 'bulldog', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5242 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['canseco'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5242 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['atlant', 'leagu'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5243 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['florida', 'gator', 'basketbal'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5243 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['brush', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5244 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lake', 'forest', 'high', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5244 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['rypien'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5244 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['wbbz'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5244 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['intern', 'seri'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5244 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['uc', 'davi', 'aggi', 'footbal', 'team'] named_entities_arr= ['DATE', 'PERSON'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5244 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['umass', 'minutemen', 'footbal', 'team'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5245 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['shumpert'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5245 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['miami', 'redskin', 'footbal', 'team'] named_entities_arr= ['DATE', 'ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5245 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['jamarcus'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5245 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['nc', 'state', 'wolfpack', 'footbal', 'team'] named_entities_arr= ['DATE', 'EVENT'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5246 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['grandal'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5246 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['cornel', 'green'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5246 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['schottenheim'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5246 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['kptk'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5246 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['schwarzenbach', 'ober', 'argen'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5247 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['nc', 'state', 'wolfpack', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5247 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['hardi', 'middl', 'school'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5247 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['australian', 'basketbal', 'team'] named_entities_arr= ['NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5247 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['colleg', 'footbal', 'season'] named_entities_arr= ['DATE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5247 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['csonka'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5248 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['stingley'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5248 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['western', 'state'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5248 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['mashburn'] named_entities_arr= ['GPE'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5248 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['lehigh', 'valley', 'steelhawk', 'season'] named_entities_arr= ['DATE', 'LOC'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5249 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['san', 'jose', 'state', 'spartan', 'footbal', 'team'] named_entities_arr= ['DATE', 'GPE', 'NORP'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5249 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['al', 'down'] named_entities_arr= ['ORG'] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.5249 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['millikin'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.525 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['eastern', 'indiana', 'confer'] named_entities_arr= [] weight= 1
#
# Rows processed: 0.0 %, count =  0
# Elapsed time: 0.525 min
#
# Last row's processing vars:
# i= 0 title_parsed_arr= ['defens', 'team'] named_entities_arr= ['ORG'] weight= 1
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 0.53 min

# %%
# this is just an id2word mapping (the integer keys here are ids, not counts)
art_dictionary = gensim.corpora.Dictionary(article_docs)

# check results
i = 0
for k, v in art_dictionary.iteritems():
    print(k, v)
    i += 1
    if i > 5:
        break
# Out:
# 9265 daz
# 13082 ljubljana
# 323 cardin
# 14173 paok
# 18622 plaster
# 2174 glove

# %%
# check results
i = 0
for k, v in art_dictionary.iteritems():
    print(k, v)
    print("freq=", art_dictionary.dfs[k])
    i += 1
    if i > 5:
        break
# Out:
# 9265 daz
# freq= 6
# 13082 ljubljana
# freq= 8
# 323 cardin
# freq= 2134
# 14173 paok
# freq= 4
# 18622 plaster
# freq= 3
# 2174 glove
# freq= 58

# %%
# check results
i = 0
for k, v in art_dictionary.iteritems():
    print(k, v)
    print("freq=", art_dictionary.dfs[k])
    i += 1
    if i > 5:
        break
# Out:
# 9265 daz
# freq= 1
# 13082 ljubljana
# freq= 2
# 323 cardin
# freq= 407
# 14173 paok
# freq= 1
# 18622 plaster
# freq= 1
# 2174 glove
# freq= 9

# %%
type(art_dictionary.dfs)
# Out:
# dict

# %%
top_freq_word_ids = sorted(art_dictionary.dfs, key=art_dictionary.dfs.__getitem__, reverse=True)[:20]
top_freq_word_ids[:5]
# Out:
# [0, 5, 38, 2, 329]

# %%
for idx in top_freq_word_ids:
    print("token=", art_dictionary[idx], "\tfreq=", art_dictionary.dfs[idx])
# Out:
# token= ORG 	freq= 147752
# token= DATE 	freq= 90967
# token= GPE 	freq= 68997
# token= footbal 	freq= 67015
# token= team 	freq= 46758
# token= season 	freq= 38095
# token= PERSON 	freq= 31308
# token= school 	freq= 27011
# token= NORP 	freq= 21380
# token= basketbal 	freq= 21021
# token= high 	freq= 20430
# token= list 	freq= 18015
# token= american 	freq= 17992
# token= EVENT 	freq= 16458
# token= CARDINAL 	freq= 15315
# token= state 	freq= 14340
# token= leagu 	freq= 14116
# token= bowl 	freq= 11316
# token= men 	freq= 11030
# token= basebal 	freq= 9589

# %%
round(len(article_docs)*0.5)
# Out:
# 31362

# %%
# Filtering
#dictionary.filter_extremes(no_below=15, no_above=0.1, keep_n= 100000)
#art_dictionary.filter_extremes(no_above=0.1)
#art_dictionary.filter_extremes(no_below=10)
art_dictionary.filter_extremes(keep_n=round(len(article_docs)*0.5))

# %%
# make bags of words for each doc in docs list, forming the corpus input for LDA model

print("Started running at", datetime.now(), "UTC")
start_time = timer()

art_bow_corpus = [art_dictionary.doc2bow(doc) for doc in article_docs]

cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 18:12:34.019022 UTC
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 0.01 min

# %%
document_num = 0
bow_doc_x = art_bow_corpus[document_num]

for i in range(len(bow_doc_x[:10])):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     art_dictionary[bow_doc_x[i][0]], 
                                                     bow_doc_x[i][1]))
# Out:
# Word 0 ("ORG") appears 1 time.
# Word 1 ("bowl") appears 1 time.
# Word 2 ("footbal") appears 1 time.
# Word 3 ("game") appears 1 time.
# Word 4 ("ncaa") appears 1 time.

# %%
# Run LDA multicore

print("Started running at", datetime.now(), "UTC")
start_time = timer()

lda_model =  gensim.models.LdaMulticore(art_bow_corpus, 
                                   num_topics = 3, 
                                   id2word = art_dictionary,                                    
                                   passes = 20,
                                   workers = 4)


cu.printRunTime(start_time)
# Out:
# Started running at 2019-03-03 18:12:44.185875 UTC
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Runtime: 2.46 min

# %%
# ntopics = 3
for idx, topic in lda_model.print_topics(num_topics=-1, num_words=20):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.258*"GPE" + 0.128*"ORG" + 0.082*"school" + 0.056*"high" + 0.016*"FAC" + 0.016*"district" + 0.014*"stadium" + 0.013*"list" + 0.013*"citi" + 0.011*"fc" + 0.010*"sport" + 0.010*"north" + 0.010*"ohio" + 0.010*"carolina" + 0.010*"counti" + 0.009*"south" + 0.009*"field" + 0.009*"kansa" + 0.008*"wildcat" + 0.008*"LOC"
#
#
# Topic: 1
# Words: 0.101*"DATE" + 0.088*"PERSON" + 0.068*"ORG" + 0.064*"footbal" + 0.056*"NORP" + 0.053*"EVENT" + 0.042*"american" + 0.042*"leagu" + 0.029*"basketbal" + 0.029*"basebal" + 0.025*"bowl" + 0.019*"cup" + 0.019*"championship" + 0.019*"nation" + 0.016*"list" + 0.016*"women" + 0.014*"game" + 0.013*"fiba" + 0.012*"divis" + 0.012*"ncaa"
#
#
# Topic: 2
# Words: 0.167*"ORG" + 0.139*"DATE" + 0.113*"team" + 0.097*"footbal" + 0.075*"season" + 0.030*"CARDINAL" + 0.027*"state" + 0.017*"basketbal" + 0.013*"men" + 0.009*"new" + 0.008*"tiger" + 0.008*"univers" + 0.008*"colleg" + 0.006*"york" + 0.006*"bulldog" + 0.005*"nfl" + 0.005*"golden" + 0.005*"chicago" + 0.005*"georgia" + 0.005*"draft"
