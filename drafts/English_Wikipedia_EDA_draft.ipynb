# %% [markdown]
# # Exploratory data analysis
# ## Dataset: English Wikipedia clickstream for December 2018

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
# Customize matplotlib default settings
matplotlib.rcParams.update({'font.size': 16})
plt.rcParams["figure.figsize"] = (20,10)

# %%
# set up Pandas options
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 100)
pd.set_option('display.precision', 3)
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# #### Read in the data

# %%
# Read the cleaned up EN clickstream tsv file into pandas
filepath = "../data/clickstream-enwiki-2018-12_clean.tsv"
df = pd.read_csv(filepath, sep='\t', names=['prev', 'curr', 'type', 'n'])

# %%
# Replace the false missing value NaNs with string "NaN"s
df['prev'] = df['prev'].fillna('NaN')
df['curr'] = df['curr'].fillna('NaN')

# %%
df.describe(include='all')
# Out:
#                prev          curr      type            n
# count      29847736      29847736  29847736  29847736.00
# unique      1714260       5183771         3          nan
# top     other-empty  Hyphen-minus      link          nan
# freq        5093433        127578  17851574          nan
# mean            NaN           NaN       NaN       230.46
# std             NaN           NaN       NaN     90303.30
# min             NaN           NaN       NaN        10.00
# 25%             NaN           NaN       NaN        15.00
# 50%             NaN           NaN       NaN        28.00
# 75%             NaN           NaN       NaN        71.00
# max             NaN           NaN       NaN 492341152.00

# %%
df.sort_values("n", ascending=False, inplace=True)

# %%
df.head(20)
# Out:
#                     prev                                  curr      type  \
# 7908180      other-empty                             Main_Page  external
# 772288    other-external                          Hyphen-minus  external
# 765759       other-empty                          Hyphen-minus  external
# 7831692   other-internal                             Main_Page  external
# 21252458    other-search                     George_H._W._Bush  external
# 3488262      other-empty                              XHamster  external
# 23951757    other-search                           Jason_Momoa  external
# 18403529    other-search                            2.0_(film)  external
# 1830737     other-search                       Bird_Box_(film)  external
# 7897786     other-search                             Main_Page  external
# 727986         Main_Page                          Hyphen-minus     other
# 5686277     other-search                        Aquaman_(film)  external
# 25647123    other-search                              Bird_Box  external
# 4776244     other-search                       Priyanka_Chopra  external
# 20229173    other-search  List_of_most-disliked_YouTube_videos  external
# 20509526    other-search                       Freddie_Mercury  external
# 62292       other-search                      Zero_(2018_film)  external
# 17100674     other-empty                           Darth_Vader  external
# 9889788      other-empty                             Segersjön  external
# 23721128    other-search                        George_W._Bush  external
#
#                   n
# 7908180   492341152
# 772288     17676430
# 765759     15498618
# 7831692     8826536
# 21252458    4576854
# 3488262     4281194
# 23951757    3538068
# 18403529    3475113
# 1830737     3251996
# 7897786     3020671
# 727986      2838090
# 5686277     2634665
# 25647123    2328884
# 4776244     2231176
# 20229173    2226602
# 20509526    2050628
# 62292       1923035
# 17100674    1801074
# 9889788     1724261
# 23721128    1674952

# %%
edge_traffic_frequencies = df.n.value_counts()

# %%
my_alpha = 0.25
plt.scatter(edge_traffic_frequencies.index.values, edge_traffic_frequencies.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Edge traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of edge traffic volume");

# %% [markdown]
# The Wikipedia clickstream dataset is a collection of referer-requested webpage pairs (edges) with aggregated traffic count for the pair within the given month. These edges are of 3 types in the data: **external**, **link** and **other**. The external type means that the referer webpage is some webpage outside of the English Wikipedia.
#
# The exact **external** referer webpages are not specified in the data, and are instead aggregated into 5 categories (as decribed [here](https://meta.wikimedia.org/wiki/Research:Wikipedia_clickstream#Data_Preparation)):
# - **other-external**: External website referers, i.e. the user went from some external website to a Wikipedia article page.
# - **other-search**: External search referers, i.e. the user searched for something on a search engine page and from there went to a Wikipedia article page.
# - **other-internal**: Referers from some other Wikimedia project. It could be a different language Wikipedia or some other Wikimedia project that is not a Wikipedia.
# - **other-empty**: An empty referer. This can be the result of a browser homepage setting, a security measure, a bot, etc.
# - **other-other**: Any other external referer.
#
# The **link** and **other** reference types are both for edges connecting Wikipedia articles. The **link** type means that the user followed a link from one Wikipedia article to another. And the **other** type means that the user went from one Wikipedia article to another, but there was no link between them. This happens if the user gets to the second article by searching from the first article, or if the referer is spoofed.

# %% [markdown]
# Here's the distribution of traffic volume and edge counts across the 3 reference types.

# %%
edges_count = df.groupby("type").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = df.groupby("type").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

summary_by_type = pd.concat([edges_count, traffic_volume], axis=1)
summary_by_type["edges_count_pct"] = summary_by_type["edges_count"] / summary_by_type["edges_count"].sum()
summary_by_type["traffic_volume_pct"] = summary_by_type["traffic_volume"] / summary_by_type["traffic_volume"].sum()
summary_by_type["traffic_avg"] = summary_by_type["traffic_volume"]/summary_by_type["edges_count"]

summary_by_type
# Out:
#           edges_count  traffic_volume  edges_count_pct  traffic_volume_pct  \
# type
# external     10990982      5100299091             0.37                0.74
# link         17851574      1718399222             0.60                0.25
# other         1005180        60022438             0.03                0.01
#
#           traffic_avg
# type
# external       464.04
# link            96.26
# other           59.71

# %%
ax = plt.gca()
(summary_by_type[["edges_count_pct", "traffic_volume_pct"]]*100).plot(kind = "bar", ax=ax)
plt.xticks(np.arange(len(summary_by_type.index)), summary_by_type.index, rotation=0)
ax.set_title("Relative edge count and traffic volume by reference type")
ax.set_ylabel("%")

# adjust this fig size
fig = plt.gcf()
fig.set_size_inches(10,5);

# %%
external_edges = df[df.type == 'external']
link_edges = df[df.type == 'link']
other_edges = df[df.type == 'other']

# %%
external_edges_traffic_frequencies = external_edges.n.value_counts()
link_edges_traffic_frequencies = link_edges.n.value_counts()
other_edges_traffic_frequencies = other_edges.n.value_counts()

# %%
my_alpha = 0.25
plt.scatter(edge_traffic_frequencies.index.values, edge_traffic_frequencies.values, \
            c="b", label="all", alpha=my_alpha)
plt.scatter(external_edges_traffic_frequencies.index.values, external_edges_traffic_frequencies.values, \
            c="r", label="external", alpha=my_alpha)
plt.scatter(link_edges_traffic_frequencies.index.values, link_edges_traffic_frequencies.values, \
            c="g", label="link", alpha=my_alpha)
plt.scatter(other_edges_traffic_frequencies.index.values, other_edges_traffic_frequencies.values, \
            c="y", label="other", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Edge traffic volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend()

# make the legend markers opaque
for lh in plt.gca().legend().legendHandles:
    lh.set_alpha(1)


plt.title("Frequency distribution of edge traffic volume by reference type");

# %% [markdown]
# ### External reference type

# %%
external_edges.describe(include='all')
# Out:
#                prev          curr      type            n
# count      10990982      10990982  10990982  10990982.00
# unique            5       5163109         1          nan
# top     other-empty  Red_seabream  external          nan
# freq        5093433             5  10990982          nan
# mean            NaN           NaN       NaN       464.04
# std             NaN           NaN       NaN    148805.73
# min             NaN           NaN       NaN        10.00
# 25%             NaN           NaN       NaN        18.00
# 50%             NaN           NaN       NaN        38.00
# 75%             NaN           NaN       NaN       121.00
# max             NaN           NaN       NaN 492341152.00

# %%
external_edges.head(20)
# Out:
#                     prev                                  curr      type  \
# 7908180      other-empty                             Main_Page  external
# 772288    other-external                          Hyphen-minus  external
# 765759       other-empty                          Hyphen-minus  external
# 7831692   other-internal                             Main_Page  external
# 21252458    other-search                     George_H._W._Bush  external
# 3488262      other-empty                              XHamster  external
# 23951757    other-search                           Jason_Momoa  external
# 18403529    other-search                            2.0_(film)  external
# 1830737     other-search                       Bird_Box_(film)  external
# 7897786     other-search                             Main_Page  external
# 5686277     other-search                        Aquaman_(film)  external
# 25647123    other-search                              Bird_Box  external
# 4776244     other-search                       Priyanka_Chopra  external
# 20229173    other-search  List_of_most-disliked_YouTube_videos  external
# 20509526    other-search                       Freddie_Mercury  external
# 62292       other-search                      Zero_(2018_film)  external
# 17100674     other-empty                           Darth_Vader  external
# 9889788      other-empty                             Segersjön  external
# 23721128    other-search                        George_W._Bush  external
# 800530      other-search                      K.G.F:_Chapter_1  external
#
#                   n
# 7908180   492341152
# 772288     17676430
# 765759     15498618
# 7831692     8826536
# 21252458    4576854
# 3488262     4281194
# 23951757    3538068
# 18403529    3475113
# 1830737     3251996
# 7897786     3020671
# 5686277     2634665
# 25647123    2328884
# 4776244     2231176
# 20229173    2226602
# 20509526    2050628
# 62292       1923035
# 17100674    1801074
# 9889788     1724261
# 23721128    1674952
# 800530      1645911

# %%
my_alpha = 0.25
plt.scatter(external_edges_traffic_frequencies.index.values, external_edges_traffic_frequencies.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Edge traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of external edges traffic volume");

# %%
edges_count = external_edges.groupby("prev").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = external_edges.groupby("prev").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

summary = pd.concat([edges_count, traffic_volume], axis=1)
summary["edges_count_pct"] = summary["edges_count"] / summary["edges_count"].sum()
summary["traffic_volume_pct"] = summary["traffic_volume"] / summary["traffic_volume"].sum()
summary["traffic_avg"] = summary["traffic_volume"]/summary["edges_count"]

summary
# Out:
#                 edges_count  traffic_volume  edges_count_pct  \
# prev
# other-empty         5093433      1779965188             0.46
# other-external       787311       116732857             0.07
# other-internal      1348892       132349844             0.12
# other-other          374921        36972380             0.03
# other-search        3386425      3034278822             0.31
#
#                 traffic_volume_pct  traffic_avg
# prev
# other-empty                   0.35       349.46
# other-external                0.02       148.27
# other-internal                0.03        98.12
# other-other                   0.01        98.61
# other-search                  0.59       896.01

# %%
ax = plt.gca()
(summary[["edges_count_pct", "traffic_volume_pct"]]*100).plot(kind = "bar", ax=ax)
plt.xticks(np.arange(len(summary.index)), summary.index, rotation=0)
ax.set_title("Relative edge count and traffic volume by external referer category")
ax.set_ylabel("%")

# adjust this fig size
fig = plt.gcf()
fig.set_size_inches(14,5);

# %%
external_websites_edges = external_edges[external_edges.prev == 'other-external']
external_search_edges = external_edges[external_edges.prev == 'other-search']
other_wikimedia_edges = external_edges[external_edges.prev == 'other-internal']
empty_referer_edges = external_edges[external_edges.prev == 'other-empty']
external_other_edges = external_edges[external_edges.prev == 'other-other']

# %%
external_websites_edges.name = "external_websites"
external_search_edges.name = "external_search"
other_wikimedia_edges.name = "other_wikimedia"
empty_referer_edges.name = "empty_referer"
external_other_edges.name = "external_other"

# %%
external_edges_freq_dict = {}
external_edges_list = \
    [external_websites_edges, external_search_edges, other_wikimedia_edges, empty_referer_edges, external_other_edges]
for e in external_edges_list:
    external_edges_freq_dict[e.name] = e.n.value_counts()

# %%
my_alpha = 0.25
colors = matplotlib.cm.rainbow(np.linspace(0, 1, 5))
i = 0
plt.scatter(edge_traffic_frequencies.index.values, edge_traffic_frequencies.values, \
            c="b", label="all", alpha=my_alpha)
for key in external_edges_freq_dict:
    plt.scatter(external_edges_freq_dict[key].index.values, external_edges_freq_dict[key].values, \
            c=[colors[i]], label=key, alpha=my_alpha)
    i+=1
    
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Edge traffic volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.legend()

# make the legend markers opaque
for lh in plt.gca().legend().legendHandles:
    lh.set_alpha(1)

plt.title("Frequency distribution of edge traffic volume by external referer category");

# %%
from IPython.display import display

# %%
for e in external_edges_list:
    print("External referer category:", e.name)
    print("Descriptive stats")
    display(e.describe(include='all'))
    print("Top 20 observations")
    display(e.head(20))
    print("=====================")
# Out:
# External referer category: external_websites
# Descriptive stats
#                   prev                 curr      type           n
# count           787311               787311    787311   787311.00
# unique               1               787311         1         nan
# top     other-external  Paul_Barber_(actor)  external         nan
# freq            787311                    1    787311         nan
# mean               NaN                  NaN       NaN      148.27
# std                NaN                  NaN       NaN    19997.55
# min                NaN                  NaN       NaN       10.00
# 25%                NaN                  NaN       NaN       15.00
# 50%                NaN                  NaN       NaN       27.00
# 75%                NaN                  NaN       NaN       66.00
# max                NaN                  NaN       NaN 17676430.00
# Top 20 observations
#                     prev                                curr      type  \
# 772288    other-external                        Hyphen-minus  external
# 7911237   other-external                           Main_Page  external
# 17715549  other-external                            HTTP_404  external
# 7013418   other-external  Toilet-related_injuries_and_deaths  external
# 9345692   other-external                         Kotii_Reddy  external
# 4678252   other-external                             Vilnius  external
# 13233515  other-external                            OpenText  external
# 2365108   other-external                           Singapore  external
# 21826646  other-external                               China  external
# 5577541   other-external             2015_Tianjin_explosions  external
# 13381169  other-external    Certificate_of_Primary_Education  external
# 15214023  other-external                           Kathmandu  external
# 24725538  other-external                               Kyoto  external
# 3109067   other-external                            Funafuti  external
# 11084868  other-external          Korean_Broadcasting_System  external
# 4032486   other-external                     RT_(TV_network)  external
# 25324353  other-external                          IP_address  external
# 2114651   other-external                          North_Pole  external
# 13503380  other-external       List_of_country_calling_codes  external
# 18565776  other-external                               Seoul  external
#
#                  n
# 772288    17676430
# 7911237     677294
# 17715549    636210
# 7013418     499771
# 9345692     365723
# 4678252     239233
# 13233515    209113
# 2365108     209027
# 21826646    169522
# 5577541     168136
# 13381169    168095
# 15214023    163653
# 24725538    162096
# 3109067     157184
# 11084868    150278
# 4032486     143064
# 25324353    141754
# 2114651     130511
# 13503380    127025
# 18565776    123349
# =====================
# External referer category: external_search
# Descriptive stats
#                 prev       curr      type          n
# count        3386425    3386425   3386425 3386425.00
# unique             1    3386425         1        nan
# top     other-search  Neil_Sang  external        nan
# freq         3386425          1   3386425        nan
# mean             NaN        NaN       NaN     896.01
# std              NaN        NaN       NaN    9169.17
# min              NaN        NaN       NaN      10.00
# 25%              NaN        NaN       NaN      24.00
# 50%              NaN        NaN       NaN      67.00
# 75%              NaN        NaN       NaN     269.00
# max              NaN        NaN       NaN 4576854.00
# Top 20 observations
#                   prev                                   curr      type  \
# 21252458  other-search                      George_H._W._Bush  external
# 23951757  other-search                            Jason_Momoa  external
# 18403529  other-search                             2.0_(film)  external
# 1830737   other-search                        Bird_Box_(film)  external
# 7897786   other-search                              Main_Page  external
# 5686277   other-search                         Aquaman_(film)  external
# 25647123  other-search                               Bird_Box  external
# 4776244   other-search                        Priyanka_Chopra  external
# 20229173  other-search   List_of_most-disliked_YouTube_videos  external
# 20509526  other-search                        Freddie_Mercury  external
# 62292     other-search                       Zero_(2018_film)  external
# 23721128  other-search                         George_W._Bush  external
# 800530    other-search                       K.G.F:_Chapter_1  external
# 6473700   other-search                             Nick_Jonas  external
# 26953871  other-search      Spider-Man:_Into_the_Spider-Verse  external
# 4600723   other-search                         Penny_Marshall  external
# 25592374  other-search                           Jimmy_Carter  external
# 3389004   other-search                        Macaulay_Culkin  external
# 11367574  other-search  List_of_highest-grossing_Indian_films  external
# 21096730  other-search                   Mary,_Queen_of_Scots  external
#
#                 n
# 21252458  4576854
# 23951757  3538068
# 18403529  3475113
# 1830737   3251996
# 7897786   3020671
# 5686277   2634665
# 25647123  2328884
# 4776244   2231176
# 20229173  2226602
# 20509526  2050628
# 62292     1923035
# 23721128  1674952
# 800530    1645911
# 6473700   1568511
# 26953871  1553836
# 4600723   1457685
# 25592374  1370107
# 3389004   1237938
# 11367574  1198082
# 21096730  1175878
# =====================
# External referer category: other_wikimedia
# Descriptive stats
#                   prev                          curr      type          n
# count          1348892                       1348892   1348892 1348892.00
# unique               1                       1348892         1        nan
# top     other-internal  IPCC_Fifth_Assessment_Report  external        nan
# freq           1348892                             1   1348892        nan
# mean               NaN                           NaN       NaN      98.12
# std                NaN                           NaN       NaN    7675.69
# min                NaN                           NaN       NaN      10.00
# 25%                NaN                           NaN       NaN      14.00
# 50%                NaN                           NaN       NaN      24.00
# 75%                NaN                           NaN       NaN      57.00
# max                NaN                           NaN       NaN 8826536.00
# Top 20 observations
#                     prev                               curr      type        n
# 7831692   other-internal                          Main_Page  external  8826536
# 718456    other-internal                       Hyphen-minus  external  1102895
# 24135220  other-internal                   NetScout_Systems  external   164599
# 5685679   other-internal                     Aquaman_(film)  external   131946
# 1830779   other-internal                    Bird_Box_(film)  external   127234
# 21252211  other-internal                  George_H._W._Bush  external   109536
# 11460836  other-internal               Alfred_Werner_Maurer  external    99521
# 2804399   other-internal                     Saleem_Dabbour  external    95989
# 1395045   other-internal            Lists_of_deaths_by_year  external    90288
# 26953883  other-internal  Spider-Man:_Into_the_Spider-Verse  external    89905
# 26173469  other-internal                        HSL_and_HSV  external    71218
# 7710511   other-internal                              Earth  external    66056
# 28093004  other-internal         Standard_Insurance_Company  external    59388
# 651834    other-internal                          Milky_Way  external    56222
# 1485708   other-internal                  Avengers:_Endgame  external    51574
# 2849860   other-internal                   Bumblebee_(film)  external    49495
# 20509281  other-internal                    Freddie_Mercury  external    48257
# 23951801  other-internal                        Jason_Momoa  external    45797
# 24879109  other-internal                       Go,_Dog._Go!  external    45587
# 18403640  other-internal                         2.0_(film)  external    44383
# =====================
# External referer category: empty_referer
# Descriptive stats
#                prev                 curr      type            n
# count       5093433              5093433   5093433   5093433.00
# unique            1              5093433         1          nan
# top     other-empty  Cerithium_rueppelli  external          nan
# freq        5093433                    1   5093433          nan
# mean            NaN                  NaN       NaN       349.46
# std             NaN                  NaN       NaN    218285.52
# min             NaN                  NaN       NaN        10.00
# 25%             NaN                  NaN       NaN        18.00
# 50%             NaN                  NaN       NaN        35.00
# 75%             NaN                  NaN       NaN       100.00
# max             NaN                  NaN       NaN 492341152.00
# Top 20 observations
#                  prev                     curr      type          n
# 7908180   other-empty                Main_Page  external  492341152
# 765759    other-empty             Hyphen-minus  external   15498618
# 3488262   other-empty                 XHamster  external    4281194
# 17100674  other-empty              Darth_Vader  external    1801074
# 9889788   other-empty                Segersjön  external    1724261
# 1395258   other-empty  Lists_of_deaths_by_year  external    1457060
# 20816436  other-empty               Exo_(band)  external    1223507
# 11283146  other-empty      2018_FIFA_World_Cup  external    1077101
# 23951884  other-empty              Jason_Momoa  external     990366
# 6365678   other-empty                     Null  external     944711
# 9794354   other-empty         Computer_science  external     871547
# 21252525  other-empty        George_H._W._Bush  external     804462
# 18403580  other-empty               2.0_(film)  external     793408
# 19920549  other-empty             Kayden_Boche  external     650669
# 22483012  other-empty              F5_Networks  external     609357
# 1830895   other-empty          Bird_Box_(film)  external     586351
# 5686348   other-empty           Aquaman_(film)  external     582462
# 17126014  other-empty               BTS_(band)  external     535448
# 1889875   other-empty                      .us  external     527769
# 7653837   other-empty            Google_Chrome  external     520627
# =====================
# External referer category: external_other
# Descriptive stats
#                prev                                    curr      type  \
# count        374921                                  374921    374921
# unique            1                                  374921         1
# top     other-other  Bongaigaon_(Vidhan_Sabha_constituency)  external
# freq         374921                                       1    374921
# mean            NaN                                     NaN       NaN
# std             NaN                                     NaN       NaN
# min             NaN                                     NaN       NaN
# 25%             NaN                                     NaN       NaN
# 50%             NaN                                     NaN       NaN
# 75%             NaN                                     NaN       NaN
# max             NaN                                     NaN       NaN
#
#                n
# count  374921.00
# unique       nan
# top          nan
# freq         nan
# mean       98.61
# std       582.40
# min        10.00
# 25%        15.00
# 50%        27.00
# 75%        66.00
# max    182358.00
# Top 20 observations
#                  prev                                       curr      type  \
# 18403629  other-other                                 2.0_(film)  external
# 7864821   other-other                                  Main_Page  external
# 62341     other-other                           Zero_(2018_film)  external
# 800518    other-other                           K.G.F:_Chapter_1  external
# 11367499  other-other      List_of_highest-grossing_Indian_films  external
# 1519345   other-other                                 Sexy_Movie  external
# 26295856  other-other                                       XXXX  external
# 27074482  other-other            List_of_Bollywood_films_of_2018  external
# 4767645   other-other                            Blue_Film_Woman  external
# 4776132   other-other                            Priyanka_Chopra  external
# 6473763   other-other                                 Nick_Jonas  external
# 5685586   other-other                             Aquaman_(film)  external
# 2141347   other-other  Government_shutdowns_in_the_United_States  external
# 28246664  other-other                            Statue_of_Unity  external
# 17279903  other-other                           Kedarnath_(film)  external
# 2665948   other-other                              Mukesh_Ambani  external
# 8466673   other-other                                     Simmba  external
# 14424592  other-other                              Sara_Ali_Khan  external
# 22656372  other-other                2018_Men's_Hockey_World_Cup  external
# 20589154  other-other                Bigg_Boss_(Hindi_season_12)  external
#
#                n
# 18403629  182358
# 7864821    81647
# 62341      72911
# 800518     68387
# 11367499   63234
# 1519345    59806
# 26295856   57086
# 27074482   39626
# 4767645    35363
# 4776132    34612
# 6473763    33078
# 5685586    32533
# 2141347    32290
# 28246664   31638
# 17279903   31097
# 2665948    29644
# 8466673    29629
# 14424592   29397
# 22656372   29314
# 20589154   28794
# =====================

# %% [markdown]
# ### Link reference type

# %%
link_edges.describe(include='all')
# Out:
#                  prev           curr      type           n
# count        17851574       17851574  17851574 17851574.00
# unique        1703705        2598302         1         nan
# top     New_York_City  United_States      link         nan
# freq             2224           6368  17851574         nan
# mean              NaN            NaN       NaN       96.26
# std               NaN            NaN       NaN      870.84
# min               NaN            NaN       NaN       10.00
# 25%               NaN            NaN       NaN       14.00
# 50%               NaN            NaN       NaN       25.00
# 75%               NaN            NaN       NaN       56.00
# max               NaN            NaN       NaN  1166522.00

# %%
link_edges.head(20)
# Out:
#                        prev                                   curr  type  \
# 9722110         Jason_Momoa                             Lisa_Bonet  link
# 6473638     Priyanka_Chopra                             Nick_Jonas  link
# 1830750            Bird_Box                        Bird_Box_(film)  link
# 4776073          Nick_Jonas                        Priyanka_Chopra  link
# 23721511  George_H._W._Bush                         George_W._Bush  link
# 6531433   George_H._W._Bush                  Pauline_Robinson_Bush  link
# 18515291  George_H._W._Bush                           Barbara_Bush  link
# 21252092     George_W._Bush                      George_H._W._Bush  link
# 10588026  George_H._W._Bush                      Dorothy_Bush_Koch  link
# 365460          Emily_Atack                           Kate_Robbins  link
# 20924833    Macaulay_Culkin                            Brenda_Song  link
# 21552763  George_H._W._Bush                            Marvin_Bush  link
# 19498365  George_H._W._Bush                              Neil_Bush  link
# 23951875         Lisa_Bonet                            Jason_Momoa  link
# 22395534    Bird_Box_(film)                        Trevante_Rhodes  link
# 24897019     Penny_Marshall                           Tracy_Reiner  link
# 6258973   George_H._W._Bush                          Prescott_Bush  link
# 22123683  Welcome_to_Marwen                       Marwencol_(film)  link
# 11268110         Lisa_Bonet                            Zoë_Kravitz  link
# 11367547         2.0_(film)  List_of_highest-grossing_Indian_films  link
#
#                 n
# 9722110   1166522
# 6473638    596798
# 1830750    508241
# 4776073    493898
# 23721511   453809
# 6531433    419132
# 18515291   412565
# 21252092   393452
# 10588026   377785
# 365460     354577
# 20924833   346110
# 21552763   339241
# 19498365   330132
# 23951875   321970
# 22395534   309028
# 24897019   281911
# 6258973    253973
# 22123683   253955
# 11268110   250392
# 11367547   249322

# %%
my_alpha = 0.25
plt.scatter(link_edges_traffic_frequencies.index.values, link_edges_traffic_frequencies.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Edge traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of link edges traffic volume");

# %% [markdown]
# #### Start nodes

# %%
edges_count = link_edges.groupby("prev").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = link_edges.groupby("prev").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

start_nodes = pd.concat([edges_count, traffic_volume], axis=1)
start_nodes["edges_count_pct"] = start_nodes["edges_count"] / start_nodes["edges_count"].sum()
start_nodes["traffic_volume_pct"] = start_nodes["traffic_volume"] / start_nodes["traffic_volume"].sum()
start_nodes["traffic_avg"] = start_nodes["traffic_volume"]/start_nodes["edges_count"]

# %%
start_nodes.sort_values("traffic_volume", ascending=False, inplace=True)

# %%
start_nodes.describe()
# Out:
#        edges_count  traffic_volume  edges_count_pct  traffic_volume_pct  \
# count   1703705.00      1703705.00       1703705.00          1703705.00
# mean         10.48         1008.62             0.00                0.00
# std          25.90         9291.25             0.00                0.00
# min           1.00           10.00             0.00                0.00
# 25%           1.00           26.00             0.00                0.00
# 50%           3.00           86.00             0.00                0.00
# 75%           9.00          359.00             0.00                0.00
# max        2224.00      4466936.00             0.00                0.00
#
#        traffic_avg
# count   1703705.00
# mean         41.53
# std         100.88
# min          10.00
# 25%          15.00
# 50%          23.27
# 75%          41.50
# max       30491.78

# %%
pd.options.display.float_format = '{:.4f}'.format

# %%
start_nodes.head(20)
# Out:
#                                    edges_count  traffic_volume  \
# prev
# George_H._W._Bush                          811         4466936
# Aquaman_(film)                             250         2391941
# Jason_Momoa                                 96         2226611
# Bird_Box_(film)                             67         2042949
# Spider-Man:_Into_the_Spider-Verse          319         1872733
# Exo_(band)                                 129         1639704
# Macaulay_Culkin                            164         1441673
# George_W._Bush                             562         1343059
# Priyanka_Chopra                            423         1245686
# 2018_in_film                              1600         1194859
# Freddie_Mercury                            321         1155736
# 2.0_(film)                                 206         1127380
# Queen_(band)                               471         1066275
# Nick_Jonas                                 194         1052197
# Penny_Marshall                             171         1015000
# Donald_Trump                               784          933626
# Miss_Universe_2018                         511          921843
# Avengers:_Endgame                          284          921604
# Bumblebee_(film)                           189          895924
# Elizabeth_II                               502          872937
#
#                                    edges_count_pct  traffic_volume_pct  \
# prev
# George_H._W._Bush                           0.0000              0.0026
# Aquaman_(film)                              0.0000              0.0014
# Jason_Momoa                                 0.0000              0.0013
# Bird_Box_(film)                             0.0000              0.0012
# Spider-Man:_Into_the_Spider-Verse           0.0000              0.0011
# Exo_(band)                                  0.0000              0.0010
# Macaulay_Culkin                             0.0000              0.0008
# George_W._Bush                              0.0000              0.0008
# Priyanka_Chopra                             0.0000              0.0007
# 2018_in_film                                0.0001              0.0007
# Freddie_Mercury                             0.0000              0.0007
# 2.0_(film)                                  0.0000              0.0007
# Queen_(band)                                0.0000              0.0006
# Nick_Jonas                                  0.0000              0.0006
# Penny_Marshall                              0.0000              0.0006
# Donald_Trump                                0.0000              0.0005
# Miss_Universe_2018                          0.0000              0.0005
# Avengers:_Endgame                           0.0000              0.0005
# Bumblebee_(film)                            0.0000              0.0005
# Elizabeth_II                                0.0000              0.0005
#
#                                    traffic_avg
# prev
# George_H._W._Bush                    5507.9359
# Aquaman_(film)                       9567.7640
# Jason_Momoa                         23193.8646
# Bird_Box_(film)                     30491.7761
# Spider-Man:_Into_the_Spider-Verse    5870.6364
# Exo_(band)                          12710.8837
# Macaulay_Culkin                      8790.6890
# George_W._Bush                       2389.7847
# Priyanka_Chopra                      2944.8842
# 2018_in_film                          746.7869
# Freddie_Mercury                      3600.4237
# 2.0_(film)                           5472.7184
# Queen_(band)                         2263.8535
# Nick_Jonas                           5423.6959
# Penny_Marshall                       5935.6725
# Donald_Trump                         1190.8495
# Miss_Universe_2018                   1803.9980
# Avengers:_Endgame                    3245.0845
# Bumblebee_(film)                     4740.3386
# Elizabeth_II                         1738.9183

# %%
start_nodes_traffic_freq = start_nodes.traffic_volume.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_freq.index.values, start_nodes_traffic_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume");

# %%
my_alpha = 0.45
plt.scatter(start_nodes_traffic_freq[:100].index.values, start_nodes_traffic_freq[:100].values, \
            c="b", alpha=my_alpha)
#plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume");

# %%
start_nodes_traffic_freq.sort_index().head(30)
# Out:
# 10    70036
# 11    54370
# 12    43368
# 13    34912
# 14    28593
# 15    24009
# 16    20106
# 17    16738
# 18    14452
# 19    12403
# 20    15242
# 21    16179
# 22    16532
# 23    16656
# 24    15954
# 25    15269
# 26    14254
# 27    13566
# 28    12816
# 29    12096
# 30    11607
# 31    11208
# 32    10952
# 33    10892
# 34    10602
# 35    10476
# 36    10161
# 37     9784
# 38     9750
# 39     9301
# Name: traffic_volume, dtype: int64

# %%
link_edges_100_cutoff = link_edges[link_edges.n >= 100]

# %%
edges_count = link_edges_100_cutoff.groupby("prev").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = link_edges_100_cutoff.groupby("prev").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

start_nodes_c100 = pd.concat([edges_count, traffic_volume], axis=1)
start_nodes_c100["edges_count_pct"] = start_nodes_c100["edges_count"] / start_nodes_c100["edges_count"].sum()
start_nodes_c100["traffic_volume_pct"] = start_nodes_c100["traffic_volume"] / start_nodes_c100["traffic_volume"].sum()

# %%
start_nodes_traffic_freq2 = start_nodes_c100.traffic_volume.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_freq2.index.values, start_nodes_traffic_freq2.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume, cutoff=100");

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_freq2[:500].index.values, start_nodes_traffic_freq2[:500].values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume, cutoff=100");

# %%
link_edges_500_cutoff = link_edges[link_edges.n >= 500]

# %%
edges_count = link_edges_500_cutoff.groupby("prev").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = link_edges_500_cutoff.groupby("prev").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

start_nodes_c500 = pd.concat([edges_count, traffic_volume], axis=1)
start_nodes_c500["edges_count_pct"] = start_nodes_c500["edges_count"] / start_nodes_c500["edges_count"].sum()
start_nodes_c500["traffic_volume_pct"] = start_nodes_c500["traffic_volume"] / start_nodes_c500["traffic_volume"].sum()

# %%
start_nodes_traffic_freq3 = start_nodes_c500.traffic_volume.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_freq3.index.values, start_nodes_traffic_freq3.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume, cutoff=500");

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_freq3[:1500].index.values, start_nodes_traffic_freq3[:1500].values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume, cutoff=500");

# %%
start_nodes.sort_values("edges_count", ascending=False).head(20)
# Out:
#                               edges_count  traffic_volume  edges_count_pct  \
# prev
# New_York_City                        2224          196519           0.0001
# London                               2061          170028           0.0001
# William_Shakespeare                  2043          231056           0.0001
# Russia                               2039          225218           0.0001
# California                           2039          135372           0.0001
# France                               1874          173974           0.0001
# United_States                        1815          557659           0.0001
# Paris                                1804          106901           0.0001
# Massachusetts                        1753           88968           0.0001
# American_Football_Conference         1747           32615           0.0001
# Germany                              1736          204390           0.0001
# United_Kingdom                       1715          278091           0.0001
# Chicago                              1713           96157           0.0001
# Spain                                1608          129799           0.0001
# 2018_in_film                         1600         1194859           0.0001
# Philadelphia                         1587           66014           0.0001
# List_of_PlayStation_2_games          1550           53038           0.0001
# List_of_Warner_Bros._films           1452           75534           0.0001
# Afghanistan                          1448          121649           0.0001
# Netherlands                          1448          135970           0.0001
#
#                               traffic_volume_pct  traffic_avg
# prev
# New_York_City                             0.0001      88.3629
# London                                    0.0001      82.4978
# William_Shakespeare                       0.0001     113.0964
# Russia                                    0.0001     110.4551
# California                                0.0001      66.3914
# France                                    0.0001      92.8356
# United_States                             0.0003     307.2501
# Paris                                     0.0001      59.2578
# Massachusetts                             0.0001      50.7519
# American_Football_Conference              0.0000      18.6691
# Germany                                   0.0001     117.7362
# United_Kingdom                            0.0002     162.1522
# Chicago                                   0.0001      56.1337
# Spain                                     0.0001      80.7208
# 2018_in_film                              0.0007     746.7869
# Philadelphia                              0.0000      41.5967
# List_of_PlayStation_2_games               0.0000      34.2181
# List_of_Warner_Bros._films                0.0000      52.0207
# Afghanistan                               0.0001      84.0117
# Netherlands                               0.0001      93.9019

# %%
start_nodes_edge_counts_freq = start_nodes.edges_count.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_edge_counts_freq.index.values, start_nodes_edge_counts_freq.values, \
            c="b", alpha=my_alpha)
#plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing edge counts')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing edge counts");

# %%
my_alpha = 0.25
plt.scatter(start_nodes_edge_counts_freq.index.values, start_nodes_edge_counts_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing edge counts')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing edge counts");

# %%
start_nodes.sort_values("edges_count", ascending=False).head(20)
# Out:
#                               edges_count  traffic_volume  edges_count_pct  \
# prev
# New_York_City                        2224          196519           0.0001
# London                               2061          170028           0.0001
# William_Shakespeare                  2043          231056           0.0001
# Russia                               2039          225218           0.0001
# California                           2039          135372           0.0001
# France                               1874          173974           0.0001
# United_States                        1815          557659           0.0001
# Paris                                1804          106901           0.0001
# Massachusetts                        1753           88968           0.0001
# American_Football_Conference         1747           32615           0.0001
# Germany                              1736          204390           0.0001
# United_Kingdom                       1715          278091           0.0001
# Chicago                              1713           96157           0.0001
# Spain                                1608          129799           0.0001
# 2018_in_film                         1600         1194859           0.0001
# Philadelphia                         1587           66014           0.0001
# List_of_PlayStation_2_games          1550           53038           0.0001
# List_of_Warner_Bros._films           1452           75534           0.0001
# Afghanistan                          1448          121649           0.0001
# Netherlands                          1448          135970           0.0001
#
#                               traffic_volume_pct  traffic_avg
# prev
# New_York_City                             0.0001      88.3629
# London                                    0.0001      82.4978
# William_Shakespeare                       0.0001     113.0964
# Russia                                    0.0001     110.4551
# California                                0.0001      66.3914
# France                                    0.0001      92.8356
# United_States                             0.0003     307.2501
# Paris                                     0.0001      59.2578
# Massachusetts                             0.0001      50.7519
# American_Football_Conference              0.0000      18.6691
# Germany                                   0.0001     117.7362
# United_Kingdom                            0.0002     162.1522
# Chicago                                   0.0001      56.1337
# Spain                                     0.0001      80.7208
# 2018_in_film                              0.0007     746.7869
# Philadelphia                              0.0000      41.5967
# List_of_PlayStation_2_games               0.0000      34.2181
# List_of_Warner_Bros._films                0.0000      52.0207
# Afghanistan                               0.0001      84.0117
# Netherlands                               0.0001      93.9019

# %%
start_nodes_traffic_avg_freq = start_nodes.traffic_avg.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_avg_freq.index.values, start_nodes_traffic_avg_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing edge traffic average per node')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing edge traffic averages per node");

# %% [markdown]
# #### Top authorities

# %%
edges_count = link_edges.groupby("curr").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = link_edges.groupby("curr").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

end_nodes = pd.concat([edges_count, traffic_volume], axis=1)
end_nodes["edges_count_pct"] = end_nodes["edges_count"] / end_nodes["edges_count"].sum()
end_nodes["traffic_volume_pct"] = end_nodes["traffic_volume"] / end_nodes["traffic_volume"].sum()
end_nodes["traffic_avg"] = end_nodes["traffic_volume"]/end_nodes["edges_count"]

# %%
end_nodes.sort_values("traffic_volume", ascending=False, inplace=True)

# %%
end_nodes.describe()
# Out:
#        edges_count  traffic_volume  edges_count_pct  traffic_volume_pct  \
# count 2598302.0000    2598302.0000     2598302.0000        2598302.0000
# mean        6.8705        661.3547           0.0000              0.0000
# std        20.7608       4031.2270           0.0000              0.0000
# min         1.0000         10.0000           0.0000              0.0000
# 25%         1.0000         26.0000           0.0000              0.0000
# 50%         2.0000         79.0000           0.0000              0.0000
# 75%         6.0000        302.0000           0.0000              0.0000
# max      6368.0000    1217004.0000           0.0004              0.0007
#
#        traffic_avg
# count 2598302.0000
# mean       65.1580
# std       359.7287
# min        10.0000
# 25%        17.0000
# 50%        29.7000
# 75%        57.2000
# max    202678.0000

# %%
end_nodes.head(20)
# Out:
#                              edges_count  traffic_volume  edges_count_pct  \
# curr
# Lisa_Bonet                            53         1217004           0.0000
# George_H._W._Bush                    956         1108189           0.0001
# George_W._Bush                      1002          907853           0.0001
# Nick_Jonas                           152          776311           0.0000
# Bird_Box_(film)                       42          682992           0.0000
# Jason_Momoa                           91          639353           0.0000
# Dorothy_Bush_Koch                     34          605207           0.0000
# Avengers:_Endgame                    230          603912           0.0000
# Zoë_Kravitz                           90          598633           0.0000
# Barbara_Bush                         117          594183           0.0000
# Priyanka_Chopra                      283          575481           0.0000
# Pauline_Robinson_Bush                 20          547034           0.0000
# Marvin_Bush                           35          545761           0.0000
# Neil_Bush                             44          516722           0.0000
# List_of_Hindi_film_families          143          500914           0.0000
# Jeb_Bush                             157          450808           0.0000
# Jimmy_Carter                         620          442623           0.0000
# Elizabeth_II                        1322          439492           0.0001
# Miguel_Ángel_Félix_Gallardo           27          422015           0.0000
# Bush_family                           90          414957           0.0000
#
#                              traffic_volume_pct  traffic_avg
# curr
# Lisa_Bonet                               0.0007   22962.3396
# George_H._W._Bush                        0.0006    1159.1935
# George_W._Bush                           0.0005     906.0409
# Nick_Jonas                               0.0005    5107.3092
# Bird_Box_(film)                          0.0004   16261.7143
# Jason_Momoa                              0.0004    7025.8571
# Dorothy_Bush_Koch                        0.0004   17800.2059
# Avengers:_Endgame                        0.0004    2625.7043
# Zoë_Kravitz                              0.0003    6651.4778
# Barbara_Bush                             0.0003    5078.4872
# Priyanka_Chopra                          0.0003    2033.5018
# Pauline_Robinson_Bush                    0.0003   27351.7000
# Marvin_Bush                              0.0003   15593.1714
# Neil_Bush                                0.0003   11743.6818
# List_of_Hindi_film_families              0.0003    3502.8951
# Jeb_Bush                                 0.0003    2871.3885
# Jimmy_Carter                             0.0003     713.9081
# Elizabeth_II                             0.0003     332.4448
# Miguel_Ángel_Félix_Gallardo              0.0002   15630.1852
# Bush_family                              0.0002    4610.6333

# %%
link_edges[(link_edges.curr == "Lisa_Bonet") & (link_edges.n >= 100)]
# Out:
#                                       prev        curr  type        n
# 9722110                        Jason_Momoa  Lisa_Bonet  link  1166522
# 9722134                      Lenny_Kravitz  Lisa_Bonet  link    29832
# 9722104                    Denise_Huxtable  Lisa_Bonet  link     4344
# 9722144                     The_Cosby_Show  Lisa_Bonet  link     4060
# 9722105                     Road_to_Paloma  Lisa_Bonet  link     3170
# 9722123                  A_Different_World  Lisa_Bonet  link     2407
# 9722107                        Angel_Heart  Lisa_Bonet  link     1562
# 9722091          Enemy_of_the_State_(film)  Lisa_Bonet  link     1172
# 9722102               High_Fidelity_(film)  Lisa_Bonet  link      797
# 9722097                        Ray_Donovan  Lisa_Bonet  link      436
# 9722142  List_of_The_Cosby_Show_characters  Lisa_Bonet  link      387
# 9722103                         Biker_Boyz  Lisa_Bonet  link      252
# 9722113           The_Red_Road_(TV_series)  Lisa_Bonet  link      188
# 9722087      List_of_African-American_Jews  Lisa_Bonet  link      180
# 9722130                        Jasmine_Guy  Lisa_Bonet  link      169
# 9722095                      Mickey_Rourke  Lisa_Bonet  link      168
# 9722094                  Sinbad_(comedian)  Lisa_Bonet  link      148

# %%
end_nodes.tail(10)
# Out:
#                           edges_count  traffic_volume  edges_count_pct  \
# curr
# We_Can't_Dance_(band)               1              10           0.0000
# Levicar                             1              10           0.0000
# Levina                              1              10           0.0000
# Levis_(motorcycle)                  1              10           0.0000
# Leviton_(disambiguation)            1              10           0.0000
# Leviton_(quasiparticle)             1              10           0.0000
# Levivirus                           1              10           0.0000
# Levoketoconazole                    1              10           0.0000
# Levolution_(album)                  1              10           0.0000
# 高雄                                  1              10           0.0000
#
#                           traffic_volume_pct  traffic_avg
# curr
# We_Can't_Dance_(band)                 0.0000      10.0000
# Levicar                               0.0000      10.0000
# Levina                                0.0000      10.0000
# Levis_(motorcycle)                    0.0000      10.0000
# Leviton_(disambiguation)              0.0000      10.0000
# Leviton_(quasiparticle)               0.0000      10.0000
# Levivirus                             0.0000      10.0000
# Levoketoconazole                      0.0000      10.0000
# Levolution_(album)                    0.0000      10.0000
# 高雄                                    0.0000      10.0000

# %%
end_nodes_traffic_freq = end_nodes.traffic_volume.value_counts()

# %%
my_alpha = 0.25
plt.scatter(end_nodes_traffic_freq.index.values, end_nodes_traffic_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming traffic volume");

# %%
my_alpha = 0.45
plt.scatter(end_nodes_traffic_freq[:100].index.values, end_nodes_traffic_freq[:100].values, \
            c="b", alpha=my_alpha)
#plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming traffic volume");

# %%
end_nodes_traffic_freq.sort_index().head(30)
# Out:
# 10    89052
# 11    73958
# 12    62474
# 13    52838
# 14    46624
# 15    40388
# 16    35574
# 17    31404
# 18    27751
# 19    24816
# 20    25743
# 21    26048
# 22    25689
# 23    25512
# 24    24748
# 25    23875
# 26    22986
# 27    22114
# 28    20960
# 29    20282
# 30    19022
# 31    18773
# 32    18516
# 33    18061
# 34    17314
# 35    16856
# 36    16513
# 37    16064
# 38    15543
# 39    15095
# Name: traffic_volume, dtype: int64

# %%
end_nodes.sort_values("edges_count", ascending=False).head(20)
# Out:
#                              edges_count  traffic_volume  edges_count_pct  \
# curr
# United_States                       6368          403347           0.0004
# India                               3855          203531           0.0002
# United_Kingdom                      3166          228569           0.0002
# World_War_II                        2578          145984           0.0001
# New_York_City                       2385          143048           0.0001
# YouTube                             2375          132473           0.0001
# Los_Angeles                         2078           93011           0.0001
# China                               2045          129257           0.0001
# IMDb                                2032           52762           0.0001
# Catholic_Church                     1946          102740           0.0001
# Order_of_the_British_Empire         1945          346382           0.0001
# California                          1879           90209           0.0001
# Canada                              1787          102870           0.0001
# Germany                             1744          108805           0.0001
# Academy_Awards                      1732          136886           0.0001
# Australia                           1670           98211           0.0001
# Soviet_Union                        1662          107503           0.0001
# Russia                              1660          104111           0.0001
# Rotten_Tomatoes                     1629           53504           0.0001
# Japan                               1544          102392           0.0001
#
#                              traffic_volume_pct  traffic_avg
# curr
# United_States                            0.0002      63.3397
# India                                    0.0001      52.7966
# United_Kingdom                           0.0001      72.1949
# World_War_II                             0.0001      56.6268
# New_York_City                            0.0001      59.9782
# YouTube                                  0.0001      55.7781
# Los_Angeles                              0.0001      44.7599
# China                                    0.0001      63.2064
# IMDb                                     0.0000      25.9656
# Catholic_Church                          0.0001      52.7955
# Order_of_the_British_Empire              0.0002     178.0884
# California                               0.0001      48.0090
# Canada                                   0.0001      57.5658
# Germany                                  0.0001      62.3882
# Academy_Awards                           0.0001      79.0335
# Australia                                0.0001      58.8090
# Soviet_Union                             0.0001      64.6829
# Russia                                   0.0001      62.7175
# Rotten_Tomatoes                          0.0000      32.8447
# Japan                                    0.0001      66.3161

# %%
end_nodes_edge_counts_freq = end_nodes.edges_count.value_counts()

# %%
my_alpha = 0.25
plt.scatter(end_nodes_edge_counts_freq.index.values, end_nodes_edge_counts_freq.values, \
            c="b", alpha=my_alpha)
#plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming edge counts')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming edge counts");

# %%
my_alpha = 0.25
plt.scatter(end_nodes_edge_counts_freq.index.values, end_nodes_edge_counts_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming edge counts')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming edge counts");

# %%
end_nodes.sort_values("traffic_avg", ascending=False).head(20)
# Out:
#                                    edges_count  traffic_volume  \
# curr
# Tasya_van_Ree                                1          202678
# List_of_Emily_Blunt_performances             1          119814
# Keanu_Reeves_filmography                     1           76607
# List_of_Hugh_Jackman_performances            1           76477
# Akshay_Kumar_filmography                     1           76431
# Marwencol_(film)                             4          299096
# Vijay_Sethupathi_filmography                 1           70201
# You_(season_1)                               1           66623
# Ryan_Reynolds_filmography                    1           66521
# Sandra_Bullock_filmography                   2          124751
# Liam_Neeson_filmography                      1           61098
# Rima_Horton                                  1           56177
# Robert_Downey_Jr._filmography                1           56015
# Jake_Gyllenhaal_filmography                  1           55182
# Nicole_Kidman_filmography                    1           53965
# Emilie_Livingston                            1           53708
# Sauli_Koskinen                               1           53223
# Allu_Arjun,_roles_and_awards                 1           49424
# Dick_Van_Dyke_filmography                    1           47767
# Andy_Serkis_filmography                      1           46716
#
#                                    edges_count_pct  traffic_volume_pct  \
# curr
# Tasya_van_Ree                               0.0000              0.0001
# List_of_Emily_Blunt_performances            0.0000              0.0001
# Keanu_Reeves_filmography                    0.0000              0.0000
# List_of_Hugh_Jackman_performances           0.0000              0.0000
# Akshay_Kumar_filmography                    0.0000              0.0000
# Marwencol_(film)                            0.0000              0.0002
# Vijay_Sethupathi_filmography                0.0000              0.0000
# You_(season_1)                              0.0000              0.0000
# Ryan_Reynolds_filmography                   0.0000              0.0000
# Sandra_Bullock_filmography                  0.0000              0.0001
# Liam_Neeson_filmography                     0.0000              0.0000
# Rima_Horton                                 0.0000              0.0000
# Robert_Downey_Jr._filmography               0.0000              0.0000
# Jake_Gyllenhaal_filmography                 0.0000              0.0000
# Nicole_Kidman_filmography                   0.0000              0.0000
# Emilie_Livingston                           0.0000              0.0000
# Sauli_Koskinen                              0.0000              0.0000
# Allu_Arjun,_roles_and_awards                0.0000              0.0000
# Dick_Van_Dyke_filmography                   0.0000              0.0000
# Andy_Serkis_filmography                     0.0000              0.0000
#
#                                    traffic_avg
# curr
# Tasya_van_Ree                      202678.0000
# List_of_Emily_Blunt_performances   119814.0000
# Keanu_Reeves_filmography            76607.0000
# List_of_Hugh_Jackman_performances   76477.0000
# Akshay_Kumar_filmography            76431.0000
# Marwencol_(film)                    74774.0000
# Vijay_Sethupathi_filmography        70201.0000
# You_(season_1)                      66623.0000
# Ryan_Reynolds_filmography           66521.0000
# Sandra_Bullock_filmography          62375.5000
# Liam_Neeson_filmography             61098.0000
# Rima_Horton                         56177.0000
# Robert_Downey_Jr._filmography       56015.0000
# Jake_Gyllenhaal_filmography         55182.0000
# Nicole_Kidman_filmography           53965.0000
# Emilie_Livingston                   53708.0000
# Sauli_Koskinen                      53223.0000
# Allu_Arjun,_roles_and_awards        49424.0000
# Dick_Van_Dyke_filmography           47767.0000
# Andy_Serkis_filmography             46716.0000

# %%
link_edges[link_edges.curr == "Tasya_van_Ree"]
# Out:
#                 prev           curr  type       n
# 2044935  Amber_Heard  Tasya_van_Ree  link  202678

# %%
link_edges[(link_edges.curr == "Amber_Heard") & (link_edges.n >= 1000)]
# Out:
#                                 prev         curr  type       n
# 14536579              Aquaman_(film)  Amber_Heard  link  238964
# 14536604                   Elon_Musk  Amber_Heard  link   52377
# 14536592                 Johnny_Depp  Amber_Heard  link   46494
# 14536645               Mera_(comics)  Amber_Heard  link   11743
# 14536546        London_Fields_(film)  Amber_Heard  link    3949
# 14536559              Lily-Rose_Depp  Amber_Heard  link    3686
# 14536600             Never_Back_Down  Amber_Heard  link    2513
# 14536646               Tasya_van_Ree  Amber_Heard  link    2213
# 14536554       Justice_League_(film)  Amber_Heard  link    2009
# 14536651                 Drive_Angry  Amber_Heard  link    1990
# 14536558              3_Days_to_Kill  Amber_Heard  link    1568
# 14536596  Friday_Night_Lights_(film)  Amber_Heard  link    1395
# 14536540              Magic_Mike_XXL  Amber_Heard  link    1352
# 14536652      The_Danish_Girl_(film)  Amber_Heard  link    1264
# 14536658    Pineapple_Express_(film)  Amber_Heard  link    1256
# 14536630                  Zombieland  Amber_Heard  link    1218
# 14536663  The_Stepfather_(2009_film)  Amber_Heard  link    1143

# %%
link_edges[link_edges.curr == "List_of_Emily_Blunt_performances"]
# Out:
#                  prev                              curr  type       n
# 27612482  Emily_Blunt  List_of_Emily_Blunt_performances  link  119814

# %%
link_edges[link_edges.curr == "Keanu_Reeves_filmography"]
# Out:
#                  prev                      curr  type      n
# 8689408  Keanu_Reeves  Keanu_Reeves_filmography  link  76607

# %%
link_edges[link_edges.curr == "List_of_Hugh_Jackman_performances"]
# Out:
#                   prev                               curr  type      n
# 13962867  Hugh_Jackman  List_of_Hugh_Jackman_performances  link  76477

# %%
end_nodes_traffic_avg_freq = end_nodes.traffic_avg.value_counts()

# %%
my_alpha = 0.25
plt.scatter(end_nodes_traffic_avg_freq.index.values, end_nodes_traffic_avg_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming edge traffic average per node')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming edge traffic averages per node");

# %% [markdown]
# ### Internal search from Wikipedia pages
# 'Other' reference type

# %%
other_edges.describe(include='all')
# Out:
#              prev          curr     type            n
# count     1005180       1005180  1005180 1005180.0000
# unique     302292        414847        1          nan
# top     Main_Page  Hyphen-minus    other          nan
# freq       257794        127458  1005180          nan
# mean          NaN           NaN      NaN      59.7131
# std           NaN           NaN      NaN    3080.4576
# min           NaN           NaN      NaN      10.0000
# 25%           NaN           NaN      NaN      12.0000
# 50%           NaN           NaN      NaN      18.0000
# 75%           NaN           NaN      NaN      35.0000
# max           NaN           NaN      NaN 2838090.0000

# %%
other_edges.head(20)
# Out:
#                        prev  \
# 727986            Main_Page
# 1395264           Main_Page
# 21252593          Main_Page
# 15997541          Main_Page
# 21175288          Main_Page
# 6426095           Main_Page
# 23370493          Main_Page
# 28097656          Main_Page
# 5564468           Main_Page
# 12932182          Main_Page
# 10547349          Main_Page
# 28474008          Main_Page
# 22351728          Main_Page
# 28765583          Main_Page
# 8621397   Welcome_to_Marwen
# 22311189          Main_Page
# 12423413          Main_Page
# 27543036          Main_Page
# 21607195          Main_Page
# 16813763          Main_Page
#
#                                                        curr   type        n
# 727986                                         Hyphen-minus  other  2838090
# 1395264                             Lists_of_deaths_by_year  other  1065668
# 21252593                                  George_H._W._Bush  other   220667
# 15997541                              Yellow_vests_movement  other   178234
# 21175288                                    Balangiga_bells  other   171702
# 6426095                                           Pineapple  other   170129
# 23370493                          2018_Sunda_Strait_tsunami  other   100842
# 28097656                             2018_Strasbourg_attack  other    98728
# 5564468                                           Voyager_2  other    83172
# 12932182                                         OSIRIS-REx  other    78426
# 10547349  Allied_naval_bombardments_of_Japan_during_Worl...  other    77714
# 28474008                          Marşandiz_train_collision  other    70717
# 22351728                                   Laurence_Olivier  other    60131
# 28765583                                           Apollo_8  other    59719
# 8621397                                           Marwencol  other    58698
# 22311189                                  SY_Aurora's_drift  other    56364
# 12423413                       Jean_Baptiste_Point_du_Sable  other    55664
# 27543036                         Japanese_battleship_Nagato  other    55184
# 21607195                                       Enrico_Fermi  other    54749
# 16813763                                   Benjamin_Tillman  other    54615

# %%
my_alpha = 0.25
plt.scatter(other_edges_traffic_frequencies.index.values, other_edges_traffic_frequencies.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Edge traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of internal search edges traffic volume");

# %% [markdown]
# #### Top hubs

# %%
edges_count = other_edges.groupby("prev").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = other_edges.groupby("prev").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

start_nodes = pd.concat([edges_count, traffic_volume], axis=1)
start_nodes["edges_count_pct"] = start_nodes["edges_count"] / start_nodes["edges_count"].sum()
start_nodes["traffic_volume_pct"] = start_nodes["traffic_volume"] / start_nodes["traffic_volume"].sum()
start_nodes["traffic_avg"] = start_nodes["traffic_volume"]/start_nodes["edges_count"]

# %%
start_nodes.sort_values("traffic_volume", ascending=False, inplace=True)

# %%
start_nodes.describe()
# Out:
#        edges_count  traffic_volume  edges_count_pct  traffic_volume_pct  \
# count  302292.0000     302292.0000      302292.0000         302292.0000
# mean        3.3252        198.5578           0.0000              0.0000
# std       468.9605      59069.7268           0.0005              0.0010
# min         1.0000         10.0000           0.0000              0.0000
# 25%         1.0000         14.0000           0.0000              0.0000
# 50%         1.0000         27.0000           0.0000              0.0000
# 75%         3.0000         66.0000           0.0000              0.0000
# max    257794.0000   32475706.0000           0.2565              0.5411
#
#        traffic_avg
# count  302292.0000
# mean       25.6492
# std        97.7297
# min        10.0000
# 25%        12.5000
# 50%        17.0000
# 75%        27.0000
# max     40893.0000

# %%
start_nodes.head(20)
# Out:
#                               edges_count  traffic_volume  edges_count_pct  \
# prev
# Main_Page                          257794        32475706           0.2565
# Wiki                                 3778          138360           0.0038
# Welcome_to_Marwen                     109           72643           0.0001
# George_H._W._Bush                     377           70544           0.0004
# Ralph_Breaks_the_Internet             212           67236           0.0002
# Wikipedia                            1998           59717           0.0020
# Jason_Momoa                           183           50044           0.0002
# Aquaman_(film)                        588           46824           0.0006
# 2.0_(film)                            255           46226           0.0003
# YouTube_Rewind                         26           43048           0.0000
# The_Ballad_of_Buster_Scruggs          108           42045           0.0001
# AppNeta                                 1           40893           0.0000
# Zero_(2018_film)                      168           39419           0.0002
# Bumblebee_(film)                      266           34700           0.0003
# Viswasam                               43           34590           0.0000
# Jennifer_Aniston                       81           34024           0.0001
# Marwencol                              31           34008           0.0000
# Yellow_vests_movement                 148           32494           0.0001
# Bird_Box                               47           31944           0.0000
# Macaulay_Culkin                        77           31887           0.0001
#
#                               traffic_volume_pct  traffic_avg
# prev
# Main_Page                                 0.5411     125.9754
# Wiki                                      0.0023      36.6226
# Welcome_to_Marwen                         0.0012     666.4495
# George_H._W._Bush                         0.0012     187.1194
# Ralph_Breaks_the_Internet                 0.0011     317.1509
# Wikipedia                                 0.0010      29.8884
# Jason_Momoa                               0.0008     273.4645
# Aquaman_(film)                            0.0008      79.6327
# 2.0_(film)                                0.0008     181.2784
# YouTube_Rewind                            0.0007    1655.6923
# The_Ballad_of_Buster_Scruggs              0.0007     389.3056
# AppNeta                                   0.0007   40893.0000
# Zero_(2018_film)                          0.0007     234.6369
# Bumblebee_(film)                          0.0006     130.4511
# Viswasam                                  0.0006     804.4186
# Jennifer_Aniston                          0.0006     420.0494
# Marwencol                                 0.0006    1097.0323
# Yellow_vests_movement                     0.0005     219.5541
# Bird_Box                                  0.0005     679.6596
# Macaulay_Culkin                           0.0005     414.1169

# %%
start_nodes_traffic_freq = start_nodes.traffic_volume.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_freq.index.values, start_nodes_traffic_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume");

# %%
my_alpha = 0.45
plt.scatter(start_nodes_traffic_freq[:100].index.values, start_nodes_traffic_freq[:100].values, \
            c="b", alpha=my_alpha)
#plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing traffic volume");

# %%
start_nodes_traffic_freq.sort_index().head(10)
# Out:
# 10    26164
# 11    20095
# 12    15955
# 13    12713
# 14    10129
# 15     8315
# 16     7022
# 17     5802
# 18     4926
# 19     4114
# Name: traffic_volume, dtype: int64

# %%
start_nodes.sort_values("edges_count", ascending=False).head(20)
# Out:
#                                                     edges_count  \
# prev
# Main_Page                                                257794
# Wiki                                                       3778
# Wikipedia                                                  1998
# Aquaman_(film)                                              588
# English_Wikipedia                                           539
# Bird_Box_(film)                                             413
# Spider-Man:_Into_the_Spider-Verse                           407
# 2018_in_film                                                394
# George_H._W._Bush                                           377
# Kader_Khan                                                  303
# Avengers:_Endgame                                           272
# Bumblebee_(film)                                            266
# 2.0_(film)                                                  255
# List_of_Tamil_films_of_2018                                 234
# Venom_(2018_film)                                           233
# United_States                                               217
# List_of_classical_music_composers_by_era                    217
# Mary_Poppins_Returns                                        213
# Ralph_Breaks_the_Internet                                   212
# List_of_research_universities_in_the_United_States          200
#
#                                                     traffic_volume  \
# prev
# Main_Page                                                 32475706
# Wiki                                                        138360
# Wikipedia                                                    59717
# Aquaman_(film)                                               46824
# English_Wikipedia                                            20313
# Bird_Box_(film)                                              29267
# Spider-Man:_Into_the_Spider-Verse                            31021
# 2018_in_film                                                 13069
# George_H._W._Bush                                            70544
# Kader_Khan                                                   24272
# Avengers:_Endgame                                            14589
# Bumblebee_(film)                                             34700
# 2.0_(film)                                                   46226
# List_of_Tamil_films_of_2018                                  19791
# Venom_(2018_film)                                            16189
# United_States                                                14890
# List_of_classical_music_composers_by_era                      7961
# Mary_Poppins_Returns                                         17722
# Ralph_Breaks_the_Internet                                    67236
# List_of_research_universities_in_the_United_States            4196
#
#                                                     edges_count_pct  \
# prev
# Main_Page                                                    0.2565
# Wiki                                                         0.0038
# Wikipedia                                                    0.0020
# Aquaman_(film)                                               0.0006
# English_Wikipedia                                            0.0005
# Bird_Box_(film)                                              0.0004
# Spider-Man:_Into_the_Spider-Verse                            0.0004
# 2018_in_film                                                 0.0004
# George_H._W._Bush                                            0.0004
# Kader_Khan                                                   0.0003
# Avengers:_Endgame                                            0.0003
# Bumblebee_(film)                                             0.0003
# 2.0_(film)                                                   0.0003
# List_of_Tamil_films_of_2018                                  0.0002
# Venom_(2018_film)                                            0.0002
# United_States                                                0.0002
# List_of_classical_music_composers_by_era                     0.0002
# Mary_Poppins_Returns                                         0.0002
# Ralph_Breaks_the_Internet                                    0.0002
# List_of_research_universities_in_the_United_States           0.0002
#
#                                                     traffic_volume_pct  \
# prev
# Main_Page                                                       0.5411
# Wiki                                                            0.0023
# Wikipedia                                                       0.0010
# Aquaman_(film)                                                  0.0008
# English_Wikipedia                                               0.0003
# Bird_Box_(film)                                                 0.0005
# Spider-Man:_Into_the_Spider-Verse                               0.0005
# 2018_in_film                                                    0.0002
# George_H._W._Bush                                               0.0012
# Kader_Khan                                                      0.0004
# Avengers:_Endgame                                               0.0002
# Bumblebee_(film)                                                0.0006
# 2.0_(film)                                                      0.0008
# List_of_Tamil_films_of_2018                                     0.0003
# Venom_(2018_film)                                               0.0003
# United_States                                                   0.0002
# List_of_classical_music_composers_by_era                        0.0001
# Mary_Poppins_Returns                                            0.0003
# Ralph_Breaks_the_Internet                                       0.0011
# List_of_research_universities_in_the_United_States              0.0001
#
#                                                     traffic_avg
# prev
# Main_Page                                              125.9754
# Wiki                                                    36.6226
# Wikipedia                                               29.8884
# Aquaman_(film)                                          79.6327
# English_Wikipedia                                       37.6865
# Bird_Box_(film)                                         70.8644
# Spider-Man:_Into_the_Spider-Verse                       76.2187
# 2018_in_film                                            33.1701
# George_H._W._Bush                                      187.1194
# Kader_Khan                                              80.1056
# Avengers:_Endgame                                       53.6360
# Bumblebee_(film)                                       130.4511
# 2.0_(film)                                             181.2784
# List_of_Tamil_films_of_2018                             84.5769
# Venom_(2018_film)                                       69.4807
# United_States                                           68.6175
# List_of_classical_music_composers_by_era                36.6866
# Mary_Poppins_Returns                                    83.2019
# Ralph_Breaks_the_Internet                              317.1509
# List_of_research_universities_in_the_United_States      20.9800

# %%
start_nodes_edge_counts_freq = start_nodes.edges_count.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_edge_counts_freq.index.values, start_nodes_edge_counts_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing edge counts')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing edge counts");

# %%
start_nodes.sort_values("traffic_avg", ascending=False).head(20)
# Out:
#                                         edges_count  traffic_volume  \
# prev
# AppNeta                                           1           40893
# Jock_McKeen                                       1           27418
# Check_verification_service                        2           22147
# Liliana_Mumy                                      3            8342
# Keisha_Grey                                       4            9566
# Balaji_Tharaneetharan                             3            6542
# 2005_in_music                                     1            2008
# Grimes_(musician)                                12           21940
# Blue_Film_Woman                                   8           14373
# YouTube_Rewind                                   26           43048
# Charlotte_Kemp_Muhl                               1            1639
# Sofia_Boutella                                    5            7984
# Jeremie_Lynch                                     1            1593
# Caitlin_Stasey                                    2            3125
# Daayan_(TV_series)                                5            7779
# Freedom-class_littoral_combat_ship                3            4526
# A.J._Applegate                                    6            9049
# Baba_Amte                                         4            5902
# List_of_snooker_records_and_statistics            1            1421
# Misty_Stone                                       3            4116
#
#                                         edges_count_pct  traffic_volume_pct  \
# prev
# AppNeta                                          0.0000              0.0007
# Jock_McKeen                                      0.0000              0.0005
# Check_verification_service                       0.0000              0.0004
# Liliana_Mumy                                     0.0000              0.0001
# Keisha_Grey                                      0.0000              0.0002
# Balaji_Tharaneetharan                            0.0000              0.0001
# 2005_in_music                                    0.0000              0.0000
# Grimes_(musician)                                0.0000              0.0004
# Blue_Film_Woman                                  0.0000              0.0002
# YouTube_Rewind                                   0.0000              0.0007
# Charlotte_Kemp_Muhl                              0.0000              0.0000
# Sofia_Boutella                                   0.0000              0.0001
# Jeremie_Lynch                                    0.0000              0.0000
# Caitlin_Stasey                                   0.0000              0.0001
# Daayan_(TV_series)                               0.0000              0.0001
# Freedom-class_littoral_combat_ship               0.0000              0.0001
# A.J._Applegate                                   0.0000              0.0002
# Baba_Amte                                        0.0000              0.0001
# List_of_snooker_records_and_statistics           0.0000              0.0000
# Misty_Stone                                      0.0000              0.0001
#
#                                         traffic_avg
# prev
# AppNeta                                  40893.0000
# Jock_McKeen                              27418.0000
# Check_verification_service               11073.5000
# Liliana_Mumy                              2780.6667
# Keisha_Grey                               2391.5000
# Balaji_Tharaneetharan                     2180.6667
# 2005_in_music                             2008.0000
# Grimes_(musician)                         1828.3333
# Blue_Film_Woman                           1796.6250
# YouTube_Rewind                            1655.6923
# Charlotte_Kemp_Muhl                       1639.0000
# Sofia_Boutella                            1596.8000
# Jeremie_Lynch                             1593.0000
# Caitlin_Stasey                            1562.5000
# Daayan_(TV_series)                        1555.8000
# Freedom-class_littoral_combat_ship        1508.6667
# A.J._Applegate                            1508.1667
# Baba_Amte                                 1475.5000
# List_of_snooker_records_and_statistics    1421.0000
# Misty_Stone                               1372.0000

# %%
other_edges[other_edges.prev == "AppNeta"]
# Out:
#             prev       curr   type      n
# 7810741  AppNeta  Main_Page  other  40893

# %%
other_edges[other_edges.prev == "Jock_McKeen"]
# Out:
#                 prev       curr   type      n
# 1677693  Jock_McKeen  Undefined  other  27418

# %%
other_edges[other_edges.prev == "Check_verification_service"]
# Out:
#                                 prev             curr   type      n
# 1677749   Check_verification_service        Undefined  other  22087
# 26078825  Check_verification_service  Cheque_clearing  other     60

# %%
other_edges[other_edges.prev == "Liliana_Mumy"]
# Out:
#                  prev                 curr   type     n
# 5694859  Liliana_Mumy  Nicky_Jones_(actor)  other  8299
# 746530   Liliana_Mumy         Hyphen-minus  other    26
# 7809977  Liliana_Mumy            Main_Page  other    17

# %%
other_edges[other_edges.prev == "Keisha_Grey"]
# Out:
#                  prev             curr   type     n
# 14261538  Keisha_Grey   A.J._Applegate  other  5328
# 6550963   Keisha_Grey  Adriana_Chechik  other  3969
# 767281    Keisha_Grey     Hyphen-minus  other   240
# 7908923   Keisha_Grey        Main_Page  other    29

# %%
other_edges[other_edges.prev == "Balaji_Tharaneetharan"]
# Out:
#                            prev              curr   type     n
# 14365912  Balaji_Tharaneetharan  Oru_Pakka_Kathai  other  6514
# 7866616   Balaji_Tharaneetharan         Main_Page  other    18
# 747642    Balaji_Tharaneetharan      Hyphen-minus  other    10

# %%
other_edges[other_edges.prev == "2005_in_music"]
# Out:
#                    prev           curr   type     n
# 11910832  2005_in_music  1956_in_music  other  2008

# %%
other_edges[other_edges.prev == "Grimes_(musician)"]
# Out:
#                        prev           curr   type     n
# 13956173  Grimes_(musician)      LessWrong  other  8041
# 18652099  Grimes_(musician)      Elon_Musk  other  7705
# 10487320  Grimes_(musician)         Rococo  other  4923
# 28488230  Grimes_(musician)       Met_Gala  other   970
# 7892416   Grimes_(musician)      Main_Page  other   139
# 781891    Grimes_(musician)   Hyphen-minus  other    49
# 5228456   Grimes_(musician)           Hana  other    33
# 6129096   Grimes_(musician)          Poppy  other    24
# 1777629   Grimes_(musician)  New_York_Post  other    21
# 21830687  Grimes_(musician)  Azealia_Banks  other    15
# 16515941  Grimes_(musician)         Mitski  other    10
# 3288005   Grimes_(musician)       Chvrches  other    10

# %%
other_edges[other_edges.prev == "Blue_Film_Woman"]
# Out:
#                      prev                  curr   type     n
# 25994196  Blue_Film_Woman         Mitsuru_Meike  other  5276
# 7809627   Blue_Film_Woman             Main_Page  other  4125
# 19049116  Blue_Film_Woman  Anarchy_in_Japansuke  other  2890
# 744345    Blue_Film_Woman          Hyphen-minus  other  1993
# 8820426   Blue_Film_Woman            Blue_movie  other    46
# 27374459  Blue_Film_Woman                   XXX  other    22
# 7345009   Blue_Film_Woman                    BF  other    11
# 25133134  Blue_Film_Woman    Sexual_intercourse  other    10

# %%
other_edges[other_edges.prev == "YouTube_Rewind"]
# Out:
#                     prev                               curr   type     n
# 988187    YouTube_Rewind                         BetterHelp  other  8709
# 8500310   YouTube_Rewind                       TotalBiscuit  other  7208
# 2038055   YouTube_Rewind                 T-Series_(company)  other  6807
# 24311093  YouTube_Rewind             Stefán_Karl_Stefánsson  other  5787
# 14000195  YouTube_Rewind                 Stephen_Hillenburg  other  3413
# 5593995   YouTube_Rewind                       XXXTentacion  other  2419
# 18338404  YouTube_Rewind                         Mac_Miller  other  2189
# 11423850  YouTube_Rewind              The_Mind_of_Jake_Paul  other  1656
# 7226782   YouTube_Rewind          Baby_(Justin_Bieber_song)  other  1270
# 21175400  YouTube_Rewind                    Stephen_Hawking  other  1074
# 14003328  YouTube_Rewind                           Stan_Lee  other   879
# 7846812   YouTube_Rewind                          Main_Page  other   534
# 2089834   YouTube_Rewind                              K-pop  other   319
# 697979    YouTube_Rewind                       Hyphen-minus  other   316
# 13586896  YouTube_Rewind                      Angry_Grandpa  other   126
# 17161824  YouTube_Rewind                           YouTuber  other   106
# 25570152  YouTube_Rewind                      Internet_meme  other    45
# 1485812   YouTube_Rewind                  Avengers:_Endgame  other    45
# 20929852  YouTube_Rewind                Harlem_Shake_(meme)  other    27
# 11283072  YouTube_Rewind                2018_FIFA_World_Cup  other    27
# 13327912  YouTube_Rewind                              Ninja  other    23
# 3325703   YouTube_Rewind         Super_Smash_Bros._Ultimate  other    20
# 21252114  YouTube_Rewind                  George_H._W._Bush  other    18
# 1677599   YouTube_Rewind                          Undefined  other    11
# 26954086  YouTube_Rewind  Spider-Man:_Into_the_Spider-Verse  other    10
# 15346911  YouTube_Rewind                             Infant  other    10

# %%
link_edges[link_edges.prev == "YouTube_Rewind"]
# Out:
#                     prev                                               curr  \
# 20229187  YouTube_Rewind               List_of_most-disliked_YouTube_videos
# 24013421  YouTube_Rewind  List_of_most-viewed_online_videos_in_the_first...
# 1833336   YouTube_Rewind                                          PewDiePie
# 2309064   YouTube_Rewind      YouTube_Rewind_2018:_Everyone_Controls_Rewind
# 15543046  YouTube_Rewind                                            YouTube
# 12450141  YouTube_Rewind                                   Marques_Brownlee
# 2933999   YouTube_Rewind                                  KSI_vs_Logan_Paul
# 18094146  YouTube_Rewind                                       Shane_Dawson
# 5581734   YouTube_Rewind                                   Ninja_(streamer)
# 2020909   YouTube_Rewind                                             Avicii
# 21763214  YouTube_Rewind                                        Trevor_Noah
# 3824536   YouTube_Rewind                                       Bethany_Mota
# 25340634  YouTube_Rewind           List_of_most-subscribed_YouTube_channels
# 23829585  YouTube_Rewind                               Portal_A_Interactive
# 15758495  YouTube_Rewind                                        John_Oliver
# 17810740  YouTube_Rewind                                              Smosh
# 15894116  YouTube_Rewind                  List_of_most-liked_YouTube_videos
# 4160352   YouTube_Rewind                                          Jake_Paul
# 16120390  YouTube_Rewind                                           Fortnite
# 9482897   YouTube_Rewind                                     Rhett_and_Link
# 22638809  YouTube_Rewind                                  The_Hood_Internet
# 11192270  YouTube_Rewind                                      Adande_Thorne
# 16428693  YouTube_Rewind                                        Lilly_Singh
# 26374506  YouTube_Rewind                                   Action_Movie_Kid
# 24263877  YouTube_Rewind                                           IJustine
# 11455437  YouTube_Rewind                             Fortnite_Battle_Royale
# 9546974   YouTube_Rewind                                      Casey_Neistat
# 3190195   YouTube_Rewind                                         Baby_Shark
# 23830594  YouTube_Rewind                                         Liza_Koshy
# 130341    YouTube_Rewind                                  YouTube_Spotlight
# 17319773  YouTube_Rewind                                      Rebecca_Black
# 12375310  YouTube_Rewind                                             Zoella
# 8418176   YouTube_Rewind                                          Lele_Pons
# 23586752  YouTube_Rewind                                         Markiplier
# 20211381  YouTube_Rewind                                       Gabbie_Hanna
# 12547496  YouTube_Rewind                                       Grace_Helbig
# 12332194  YouTube_Rewind                                         Will_Smith
# 18157987  YouTube_Rewind                                        Adam_Rippon
# 14428525  YouTube_Rewind                                       Mason_Ramsey
# 10007003  YouTube_Rewind                                        Hannah_Hart
# 26477373  YouTube_Rewind                                Kurt_Hugo_Schneider
# 15359086  YouTube_Rewind                                    Rosanna_Pansino
# 28464440  YouTube_Rewind                                        Robby_Novak
# 20369525  YouTube_Rewind                        Epic_Rap_Battles_of_History
# 14631162  YouTube_Rewind                                           Pinkfong
# 21079930  YouTube_Rewind                                 Dominic_Panganiban
# 29694546  YouTube_Rewind                                      Merrell_Twins
# 10191513  YouTube_Rewind                            Watch_Me_(Whip/Nae_Nae)
# 11286534  YouTube_Rewind                                        AsapScience
# 14466448  YouTube_Rewind                                         Bhuvan_Bam
# ...                  ...                                                ...
# 28382700  YouTube_Rewind                                  Conan_(talk_show)
# 2744453   YouTube_Rewind                                    YouTube_Premium
# 10948460  YouTube_Rewind                                        Bag_Raiders
# 9714447   YouTube_Rewind                                              Ylvis
# 26077143  YouTube_Rewind                                           J_Balvin
# 10601859  YouTube_Rewind                                Mannequin_Challenge
# 2683588   YouTube_Rewind                                      Selfie_(song)
# 24030893  YouTube_Rewind                      The_Witness_(2016_video_game)
# 25784221  YouTube_Rewind                            Let_It_Go_(Disney_song)
# 9122163   YouTube_Rewind                                            Get_Out
# 1996309   YouTube_Rewind                                      Views_(album)
# 17475682  YouTube_Rewind                           Manchester_Arena_bombing
# 14943504  YouTube_Rewind                                         MattyBRaps
# 2785067   YouTube_Rewind                                              Gamer
# 2120834   YouTube_Rewind                                    Stranger_Things
# 27955749  YouTube_Rewind                                       Dan_and_Phil
# 27133573  YouTube_Rewind                                      Rahat_Hossain
# 1352849   YouTube_Rewind                     Happy_(Pharrell_Williams_song)
# 1199469   YouTube_Rewind                                       Shake_It_Off
# 5462881   YouTube_Rewind                                            Silentó
# 18556963  YouTube_Rewind                           Fancy_(Iggy_Azalea_song)
# 26958538  YouTube_Rewind                                     Kristian_Nairn
# 19182430  YouTube_Rewind                                            I.aM.mE
# 5613801   YouTube_Rewind                              Charlie_Bit_My_Finger
# 7703207   YouTube_Rewind                       Animals_(Martin_Garrix_song)
# 26349301  YouTube_Rewind                                     Adventure_game
# 9542821   YouTube_Rewind                                    Halsey_(singer)
# 5999369   YouTube_Rewind                            2017_Chiapas_earthquake
# 16398374  YouTube_Rewind                           Famous_(Kanye_West_song)
# 16013175  YouTube_Rewind                                       Shia_LaBeouf
# 25274458  YouTube_Rewind                                 Hamilton_(musical)
# 19953936  YouTube_Rewind                                        Iggy_Azalea
# 20093438  YouTube_Rewind                         Sorry_(Justin_Bieber_song)
# 21698896  YouTube_Rewind                                               NASA
# 8989163   YouTube_Rewind               List_of_most-viewed_YouTube_channels
# 23029487  YouTube_Rewind                                   New_Rules_(song)
# 23768516  YouTube_Rewind                                      I'm_on_a_Boat
# 8451880   YouTube_Rewind                                      Ariana_Grande
# 18488700  YouTube_Rewind                                   Street_Fighter_V
# 16271013  YouTube_Rewind                                   Dominic_Sandoval
# 19203954  YouTube_Rewind                      Roses_(The_Chainsmokers_song)
# 23634459  YouTube_Rewind                                 Frozen_(2013_film)
# 14215756  YouTube_Rewind                                      We_Can't_Stop
# 26047265  YouTube_Rewind                                        Prancercise
# 9039173   YouTube_Rewind                    List_of_most-viewed_Vevo_videos
# 26301357  YouTube_Rewind                                         Kanye_West
# 16754559  YouTube_Rewind                                       Omi_(singer)
# 17261414  YouTube_Rewind                                       Alessia_Cara
# 2946896   YouTube_Rewind                                         Indie_game
# 3115526   YouTube_Rewind                      Diet_Coke_and_Mentos_eruption
#
#           type      n
# 20229187  link  43966
# 24013421  link  21142
# 1833336   link  13626
# 2309064   link  10658
# 15543046  link   6542
# 12450141  link   5180
# 2933999   link   4781
# 18094146  link   4113
# 5581734   link   3588
# 2020909   link   2827
# 21763214  link   1990
# 3824536   link   1948
# 25340634  link   1853
# 23829585  link   1825
# 15758495  link   1730
# 17810740  link   1454
# 15894116  link   1290
# 4160352   link   1281
# 16120390  link   1212
# 9482897   link   1173
# 22638809  link   1108
# 11192270  link   1083
# 16428693  link   1059
# 26374506  link    991
# 24263877  link    989
# 11455437  link    984
# 9546974   link    942
# 3190195   link    930
# 23830594  link    913
# 130341    link    819
# 17319773  link    790
# 12375310  link    786
# 8418176   link    763
# 23586752  link    759
# 20211381  link    755
# 12547496  link    747
# 12332194  link    738
# 18157987  link    698
# 14428525  link    692
# 10007003  link    626
# 26477373  link    594
# 15359086  link    577
# 28464440  link    547
# 20369525  link    525
# 14631162  link    525
# 21079930  link    489
# 29694546  link    488
# 10191513  link    472
# 11286534  link    455
# 14466448  link    453
# ...        ...    ...
# 28382700  link     18
# 2744453   link     18
# 10948460  link     18
# 9714447   link     18
# 26077143  link     18
# 10601859  link     18
# 2683588   link     17
# 24030893  link     16
# 25784221  link     16
# 9122163   link     16
# 1996309   link     16
# 17475682  link     15
# 14943504  link     15
# 2785067   link     14
# 2120834   link     14
# 27955749  link     13
# 27133573  link     13
# 1352849   link     13
# 1199469   link     13
# 5462881   link     12
# 18556963  link     12
# 26958538  link     12
# 19182430  link     12
# 5613801   link     12
# 7703207   link     12
# 26349301  link     12
# 9542821   link     12
# 5999369   link     12
# 16398374  link     12
# 16013175  link     12
# 25274458  link     12
# 19953936  link     11
# 20093438  link     11
# 21698896  link     11
# 8989163   link     11
# 23029487  link     11
# 23768516  link     11
# 8451880   link     11
# 18488700  link     11
# 16271013  link     10
# 19203954  link     10
# 23634459  link     10
# 14215756  link     10
# 26047265  link     10
# 9039173   link     10
# 26301357  link     10
# 16754559  link     10
# 17261414  link     10
# 2946896   link     10
# 3115526   link     10
#
# [406 rows x 4 columns]

# %%
searches_set = set(other_edges[other_edges.prev == "YouTube_Rewind"].curr)

# %%
links_set = set(link_edges[link_edges.prev == "YouTube_Rewind"].curr)

# %%
len(searches_set)
# Out:
# 26

# %%
len(links_set)
# Out:
# 406

# %%
intersection_set = links_set.intersection(searches_set)

# %%
intersection_set
# Out:
# set()

# %%
start_nodes_traffic_avg_freq = start_nodes.traffic_avg.value_counts()

# %%
my_alpha = 0.25
plt.scatter(start_nodes_traffic_avg_freq.index.values, start_nodes_traffic_avg_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Outgoing edge traffic average per node')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of outgoing edge traffic averages per node");

# %%
start_nodes_traffic_avg_freq.sort_index()[:11]
# Out:
# 10.0000    27269
# 10.1250        2
# 10.2000        1
# 10.2222        1
# 10.2500        3
# 10.3000        1
# 10.3333      111
# 10.4000        1
# 10.5000     1774
# 10.5556        2
# 10.5714        2
# 10.6250        1
# 10.6364        1
# 10.6667      188
# 10.7000        2
# 10.7143        1
# 10.7273        1
# 10.7333        1
# 10.7500       24
# 10.7778        1
# 10.7895        1
# 10.8000        3
# 10.8182        1
# 10.8333        2
# 10.8571        1
# 10.8889        2
# 10.9000        1
# 10.9412        1
# 11.0000    22460
# Name: traffic_avg, dtype: int64

# %% [markdown]
# #### Top authorities

# %%
edges_count = other_edges.groupby("curr").n.count()
edges_count.rename("edges_count", inplace=True)
traffic_volume = other_edges.groupby("curr").n.sum()
traffic_volume.rename("traffic_volume", inplace=True)

end_nodes = pd.concat([edges_count, traffic_volume], axis=1)
end_nodes["edges_count_pct"] = end_nodes["edges_count"] / end_nodes["edges_count"].sum()
end_nodes["traffic_volume_pct"] = end_nodes["traffic_volume"] / end_nodes["traffic_volume"].sum()
end_nodes["traffic_avg"] = end_nodes["traffic_volume"]/end_nodes["edges_count"]

# %%
end_nodes.sort_values("traffic_volume", ascending=False, inplace=True)

# %%
end_nodes.describe()
# Out:
#        edges_count  traffic_volume  edges_count_pct  traffic_volume_pct  \
# count  414847.0000     414847.0000      414847.0000         414847.0000
# mean        2.4230        144.6857           0.0000              0.0000
# std       261.4296      13425.0331           0.0003              0.0002
# min         1.0000         10.0000           0.0000              0.0000
# 25%         1.0000         14.0000           0.0000              0.0000
# 50%         1.0000         26.0000           0.0000              0.0000
# 75%         2.0000         64.0000           0.0000              0.0000
# max    127458.0000    7557718.0000           0.1268              0.1259
#
#        traffic_avg
# count  414847.0000
# mean       51.2643
# std       476.3243
# min        10.0000
# 25%        14.0000
# 50%        21.0000
# 75%        39.7071
# max     85917.5000

# %%
end_nodes.head(20)
# Out:
#                                                     edges_count  \
# curr
# Hyphen-minus                                             127458
# Main_Page                                                110009
# Lists_of_deaths_by_year                                     275
# George_H._W._Bush                                           228
# Yellow_vests_movement                                        25
# Balangiga_bells                                               2
# Pineapple                                                    27
# 2018_Sunda_Strait_tsunami                                     4
# 2018_Strasbourg_attack                                        6
# Aquaman_(film)                                              711
# Voyager_2                                                     7
# Marwencol                                                     7
# OSIRIS-REx                                                    1
# Allied_naval_bombardments_of_Japan_during_World...            1
# Marşandiz_train_collision                                     1
# Undefined                                                   242
# Spider-Man:_Into_the_Spider-Verse                           510
# Laurence_Olivier                                              1
# Apollo_8                                                      6
# SY_Aurora's_drift                                             1
#
#                                                     traffic_volume  \
# curr
# Hyphen-minus                                               7557718
# Main_Page                                                  4013760
# Lists_of_deaths_by_year                                    1074677
# George_H._W._Bush                                           226297
# Yellow_vests_movement                                       178842
# Balangiga_bells                                             171835
# Pineapple                                                   170638
# 2018_Sunda_Strait_tsunami                                   100893
# 2018_Strasbourg_attack                                       99298
# Aquaman_(film)                                               87294
# Voyager_2                                                    83285
# Marwencol                                                    79876
# OSIRIS-REx                                                   78426
# Allied_naval_bombardments_of_Japan_during_World...           77714
# Marşandiz_train_collision                                    70717
# Undefined                                                    63889
# Spider-Man:_Into_the_Spider-Verse                            61587
# Laurence_Olivier                                             60131
# Apollo_8                                                     59787
# SY_Aurora's_drift                                            56364
#
#                                                     edges_count_pct  \
# curr
# Hyphen-minus                                                 0.1268
# Main_Page                                                    0.1094
# Lists_of_deaths_by_year                                      0.0003
# George_H._W._Bush                                            0.0002
# Yellow_vests_movement                                        0.0000
# Balangiga_bells                                              0.0000
# Pineapple                                                    0.0000
# 2018_Sunda_Strait_tsunami                                    0.0000
# 2018_Strasbourg_attack                                       0.0000
# Aquaman_(film)                                               0.0007
# Voyager_2                                                    0.0000
# Marwencol                                                    0.0000
# OSIRIS-REx                                                   0.0000
# Allied_naval_bombardments_of_Japan_during_World...           0.0000
# Marşandiz_train_collision                                    0.0000
# Undefined                                                    0.0002
# Spider-Man:_Into_the_Spider-Verse                            0.0005
# Laurence_Olivier                                             0.0000
# Apollo_8                                                     0.0000
# SY_Aurora's_drift                                            0.0000
#
#                                                     traffic_volume_pct  \
# curr
# Hyphen-minus                                                    0.1259
# Main_Page                                                       0.0669
# Lists_of_deaths_by_year                                         0.0179
# George_H._W._Bush                                               0.0038
# Yellow_vests_movement                                           0.0030
# Balangiga_bells                                                 0.0029
# Pineapple                                                       0.0028
# 2018_Sunda_Strait_tsunami                                       0.0017
# 2018_Strasbourg_attack                                          0.0017
# Aquaman_(film)                                                  0.0015
# Voyager_2                                                       0.0014
# Marwencol                                                       0.0013
# OSIRIS-REx                                                      0.0013
# Allied_naval_bombardments_of_Japan_during_World...              0.0013
# Marşandiz_train_collision                                       0.0012
# Undefined                                                       0.0011
# Spider-Man:_Into_the_Spider-Verse                               0.0010
# Laurence_Olivier                                                0.0010
# Apollo_8                                                        0.0010
# SY_Aurora's_drift                                               0.0009
#
#                                                     traffic_avg
# curr
# Hyphen-minus                                            59.2958
# Main_Page                                               36.4857
# Lists_of_deaths_by_year                               3907.9164
# George_H._W._Bush                                      992.5307
# Yellow_vests_movement                                 7153.6800
# Balangiga_bells                                      85917.5000
# Pineapple                                             6319.9259
# 2018_Sunda_Strait_tsunami                            25223.2500
# 2018_Strasbourg_attack                               16549.6667
# Aquaman_(film)                                         122.7764
# Voyager_2                                            11897.8571
# Marwencol                                            11410.8571
# OSIRIS-REx                                           78426.0000
# Allied_naval_bombardments_of_Japan_during_World...   77714.0000
# Marşandiz_train_collision                            70717.0000
# Undefined                                              264.0041
# Spider-Man:_Into_the_Spider-Verse                      120.7588
# Laurence_Olivier                                     60131.0000
# Apollo_8                                              9964.5000
# SY_Aurora's_drift                                    56364.0000

# %%
end_nodes.tail(20)
# Out:
#                                       edges_count  traffic_volume  \
# curr
# Melrose_Place_(season_1)                        1              10
# Māui_(mythology)                                1              10
# A_Thousand_Acres                                1              10
# Hanjin_Shipping                                 1              10
# Fauxtography                                    1              10
# Club_Life:_Volume_Four_New_York_City            1              10
# UFF                                             1              10
# UFC_on_Fox:_Poirier_vs._Gaethje                 1              10
# Joseph_Phan                                     1              10
# UFC_on_ESPN:_Ngannou_vs._Velasquez              1              10
# UFC_Fight_Pass                                  1              10
# Singkil                                         1              10
# Joseph_O'Neill_(writer,_born_1964)              1              10
# Joseph_Newman                                   1              10
# Downtown_no_Gottsu_Ee_Kanji                     1              10
# Single-phase_electric_power                     1              10
# Joseph_Mor_Gregorios                            1              10
# Joseph_Monier                                   1              10
# Aundha_Nagnath_Temple                           1              10
# Utkarsh_Ambudkar                                1              10
#
#                                       edges_count_pct  traffic_volume_pct  \
# curr
# Melrose_Place_(season_1)                       0.0000              0.0000
# Māui_(mythology)                               0.0000              0.0000
# A_Thousand_Acres                               0.0000              0.0000
# Hanjin_Shipping                                0.0000              0.0000
# Fauxtography                                   0.0000              0.0000
# Club_Life:_Volume_Four_New_York_City           0.0000              0.0000
# UFF                                            0.0000              0.0000
# UFC_on_Fox:_Poirier_vs._Gaethje                0.0000              0.0000
# Joseph_Phan                                    0.0000              0.0000
# UFC_on_ESPN:_Ngannou_vs._Velasquez             0.0000              0.0000
# UFC_Fight_Pass                                 0.0000              0.0000
# Singkil                                        0.0000              0.0000
# Joseph_O'Neill_(writer,_born_1964)             0.0000              0.0000
# Joseph_Newman                                  0.0000              0.0000
# Downtown_no_Gottsu_Ee_Kanji                    0.0000              0.0000
# Single-phase_electric_power                    0.0000              0.0000
# Joseph_Mor_Gregorios                           0.0000              0.0000
# Joseph_Monier                                  0.0000              0.0000
# Aundha_Nagnath_Temple                          0.0000              0.0000
# Utkarsh_Ambudkar                               0.0000              0.0000
#
#                                       traffic_avg
# curr
# Melrose_Place_(season_1)                  10.0000
# Māui_(mythology)                          10.0000
# A_Thousand_Acres                          10.0000
# Hanjin_Shipping                           10.0000
# Fauxtography                              10.0000
# Club_Life:_Volume_Four_New_York_City      10.0000
# UFF                                       10.0000
# UFC_on_Fox:_Poirier_vs._Gaethje           10.0000
# Joseph_Phan                               10.0000
# UFC_on_ESPN:_Ngannou_vs._Velasquez        10.0000
# UFC_Fight_Pass                            10.0000
# Singkil                                   10.0000
# Joseph_O'Neill_(writer,_born_1964)        10.0000
# Joseph_Newman                             10.0000
# Downtown_no_Gottsu_Ee_Kanji               10.0000
# Single-phase_electric_power               10.0000
# Joseph_Mor_Gregorios                      10.0000
# Joseph_Monier                             10.0000
# Aundha_Nagnath_Temple                     10.0000
# Utkarsh_Ambudkar                          10.0000

# %%
end_nodes_traffic_freq = end_nodes.traffic_volume.value_counts()

# %%
my_alpha = 0.25
plt.scatter(end_nodes_traffic_freq.index.values, end_nodes_traffic_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming traffic volume");

# %%
my_alpha = 0.45
plt.scatter(end_nodes_traffic_freq[:100].index.values, end_nodes_traffic_freq[:100].values, \
            c="b", alpha=my_alpha)
#plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming traffic volume')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming traffic volume");

# %%
end_nodes_traffic_freq.sort_index().head(30)
# Out:
# 10    29958
# 11    24306
# 12    20706
# 13    17637
# 14    15068
# 15    13227
# 16    11528
# 17    10213
# 18     9193
# 19     8265
# 20     8059
# 21     7465
# 22     7130
# 23     6714
# 24     6415
# 25     6010
# 26     5829
# 27     5476
# 28     5255
# 29     4878
# 30     4642
# 31     4297
# 32     4158
# 33     3995
# 34     3718
# 35     3611
# 36     3578
# 37     3272
# 38     3184
# 39     3197
# Name: traffic_volume, dtype: int64

# %%
end_nodes.sort_values("edges_count", ascending=False).head(20)
# Out:
#                                    edges_count  traffic_volume  \
# curr
# Hyphen-minus                            127458         7557718
# Main_Page                               110009         4013760
# Aquaman_(film)                             711           87294
# Spider-Man:_Into_the_Spider-Verse          510           61587
# 2018_in_film                               415           38373
# Bird_Box_(film)                            329           44264
# Null                                       288            7813
# Bumblebee_(film)                           284           34584
# Lists_of_deaths_by_year                    275         1074677
# 2.0_(film)                                 268           36930
# Christian                                  266           11543
# 2019_in_film                               249           14863
# Undefined                                  242           63889
# George_H._W._Bush                          228          226297
# Ariana_Grande                              223           15849
# United_States                              218           15525
# Avengers:_Infinity_War                     216           27135
# Avengers:_Endgame                          216           24559
# Titans_(2018_TV_series)                    205           18665
# 2018                                       205           15519
#
#                                    edges_count_pct  traffic_volume_pct  \
# curr
# Hyphen-minus                                0.1268              0.1259
# Main_Page                                   0.1094              0.0669
# Aquaman_(film)                              0.0007              0.0015
# Spider-Man:_Into_the_Spider-Verse           0.0005              0.0010
# 2018_in_film                                0.0004              0.0006
# Bird_Box_(film)                             0.0003              0.0007
# Null                                        0.0003              0.0001
# Bumblebee_(film)                            0.0003              0.0006
# Lists_of_deaths_by_year                     0.0003              0.0179
# 2.0_(film)                                  0.0003              0.0006
# Christian                                   0.0003              0.0002
# 2019_in_film                                0.0002              0.0002
# Undefined                                   0.0002              0.0011
# George_H._W._Bush                           0.0002              0.0038
# Ariana_Grande                               0.0002              0.0003
# United_States                               0.0002              0.0003
# Avengers:_Infinity_War                      0.0002              0.0005
# Avengers:_Endgame                           0.0002              0.0004
# Titans_(2018_TV_series)                     0.0002              0.0003
# 2018                                        0.0002              0.0003
#
#                                    traffic_avg
# curr
# Hyphen-minus                           59.2958
# Main_Page                              36.4857
# Aquaman_(film)                        122.7764
# Spider-Man:_Into_the_Spider-Verse     120.7588
# 2018_in_film                           92.4651
# Bird_Box_(film)                       134.5410
# Null                                   27.1285
# Bumblebee_(film)                      121.7746
# Lists_of_deaths_by_year              3907.9164
# 2.0_(film)                            137.7985
# Christian                              43.3947
# 2019_in_film                           59.6908
# Undefined                             264.0041
# George_H._W._Bush                     992.5307
# Ariana_Grande                          71.0717
# United_States                          71.2156
# Avengers:_Infinity_War                125.6250
# Avengers:_Endgame                     113.6991
# Titans_(2018_TV_series)                91.0488
# 2018                                   75.7024

# %%
end_nodes_edge_counts_freq = end_nodes.edges_count.value_counts()

# %%
my_alpha = 0.25
plt.scatter(end_nodes_edge_counts_freq.index.values, end_nodes_edge_counts_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming edge counts')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming edge counts");

# %%
end_nodes.sort_values("traffic_avg", ascending=False).head(20)
# Out:
#                                                     edges_count  \
# curr
# Balangiga_bells                                               2
# OSIRIS-REx                                                    1
# Allied_naval_bombardments_of_Japan_during_World...            1
# Marşandiz_train_collision                                     1
# Laurence_Olivier                                              1
# SY_Aurora's_drift                                             1
# Jean_Baptiste_Point_du_Sable                                  1
# Enrico_Fermi                                                  1
# Benjamin_Tillman                                              1
# Other_Worlds,_Universe_Science_Fiction,_and_Sci...            1
# Carolwood_Pacific_Railroad                                    1
# List_of_artificial_objects_leaving_the_Solar_Sy...            1
# Nothomyrmecia                                                 1
# Cuban_macaw                                                   1
# The_Cloisters                                                 1
# Wihtred_of_Kent                                               1
# Bill_Slater_(footballer)                                      1
# Japanese_battleship_Nagato                                    2
# The_High_Strung                                               1
# Jordan_Lane_Price                                             1
#
#                                                     traffic_volume  \
# curr
# Balangiga_bells                                             171835
# OSIRIS-REx                                                   78426
# Allied_naval_bombardments_of_Japan_during_World...           77714
# Marşandiz_train_collision                                    70717
# Laurence_Olivier                                             60131
# SY_Aurora's_drift                                            56364
# Jean_Baptiste_Point_du_Sable                                 55664
# Enrico_Fermi                                                 54749
# Benjamin_Tillman                                             54615
# Other_Worlds,_Universe_Science_Fiction,_and_Sci...           43646
# Carolwood_Pacific_Railroad                                   43577
# List_of_artificial_objects_leaving_the_Solar_Sy...           41218
# Nothomyrmecia                                                36006
# Cuban_macaw                                                  35394
# The_Cloisters                                                32687
# Wihtred_of_Kent                                              32403
# Bill_Slater_(footballer)                                     32239
# Japanese_battleship_Nagato                                   55194
# The_High_Strung                                              27072
# Jordan_Lane_Price                                            26829
#
#                                                     edges_count_pct  \
# curr
# Balangiga_bells                                              0.0000
# OSIRIS-REx                                                   0.0000
# Allied_naval_bombardments_of_Japan_during_World...           0.0000
# Marşandiz_train_collision                                    0.0000
# Laurence_Olivier                                             0.0000
# SY_Aurora's_drift                                            0.0000
# Jean_Baptiste_Point_du_Sable                                 0.0000
# Enrico_Fermi                                                 0.0000
# Benjamin_Tillman                                             0.0000
# Other_Worlds,_Universe_Science_Fiction,_and_Sci...           0.0000
# Carolwood_Pacific_Railroad                                   0.0000
# List_of_artificial_objects_leaving_the_Solar_Sy...           0.0000
# Nothomyrmecia                                                0.0000
# Cuban_macaw                                                  0.0000
# The_Cloisters                                                0.0000
# Wihtred_of_Kent                                              0.0000
# Bill_Slater_(footballer)                                     0.0000
# Japanese_battleship_Nagato                                   0.0000
# The_High_Strung                                              0.0000
# Jordan_Lane_Price                                            0.0000
#
#                                                     traffic_volume_pct  \
# curr
# Balangiga_bells                                                 0.0029
# OSIRIS-REx                                                      0.0013
# Allied_naval_bombardments_of_Japan_during_World...              0.0013
# Marşandiz_train_collision                                       0.0012
# Laurence_Olivier                                                0.0010
# SY_Aurora's_drift                                               0.0009
# Jean_Baptiste_Point_du_Sable                                    0.0009
# Enrico_Fermi                                                    0.0009
# Benjamin_Tillman                                                0.0009
# Other_Worlds,_Universe_Science_Fiction,_and_Sci...              0.0007
# Carolwood_Pacific_Railroad                                      0.0007
# List_of_artificial_objects_leaving_the_Solar_Sy...              0.0007
# Nothomyrmecia                                                   0.0006
# Cuban_macaw                                                     0.0006
# The_Cloisters                                                   0.0005
# Wihtred_of_Kent                                                 0.0005
# Bill_Slater_(footballer)                                        0.0005
# Japanese_battleship_Nagato                                      0.0009
# The_High_Strung                                                 0.0005
# Jordan_Lane_Price                                               0.0004
#
#                                                     traffic_avg
# curr
# Balangiga_bells                                      85917.5000
# OSIRIS-REx                                           78426.0000
# Allied_naval_bombardments_of_Japan_during_World...   77714.0000
# Marşandiz_train_collision                            70717.0000
# Laurence_Olivier                                     60131.0000
# SY_Aurora's_drift                                    56364.0000
# Jean_Baptiste_Point_du_Sable                         55664.0000
# Enrico_Fermi                                         54749.0000
# Benjamin_Tillman                                     54615.0000
# Other_Worlds,_Universe_Science_Fiction,_and_Sci...   43646.0000
# Carolwood_Pacific_Railroad                           43577.0000
# List_of_artificial_objects_leaving_the_Solar_Sy...   41218.0000
# Nothomyrmecia                                        36006.0000
# Cuban_macaw                                          35394.0000
# The_Cloisters                                        32687.0000
# Wihtred_of_Kent                                      32403.0000
# Bill_Slater_(footballer)                             32239.0000
# Japanese_battleship_Nagato                           27597.0000
# The_High_Strung                                      27072.0000
# Jordan_Lane_Price                                    26829.0000

# %%
end_nodes_traffic_avg_freq = end_nodes.traffic_avg.value_counts()

# %%
my_alpha = 0.25
plt.scatter(end_nodes_traffic_avg_freq.index.values, end_nodes_traffic_avg_freq.values, \
            c="b", alpha=my_alpha)
plt.xscale("log")
plt.yscale("log")
plt.xlabel('Incoming edge traffic average per node')
plt.ylabel('Frequency')
plt.grid(True)

plt.title("Frequency distribution of incoming edge traffic averages per node");
